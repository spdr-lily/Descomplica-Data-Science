# %% [markdown]
# <a href="https://colab.research.google.com/github/spdr-lily/Data-Science-Profile/blob/main/PLN_segmentacao_de_tokens_e_sentencas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processamento de Linguagem Natural
# Segmentação de Tokens e Sentenças

# %% [markdown]
# # Carregando e entendendo o dataset

# %%
! wget -O dhbb.txt https://gist.githubusercontent.com/alvelvis/8e375f1198636813d5f6aa41453398c4/raw/4bafb00b511256ab78c259238bdb50a6ab01dc89/DHBB%2520Neudo%2520Ribeiro%2520Campos
# Out:
# --2025-05-05 19:21:33--  https://gist.githubusercontent.com/alvelvis/8e375f1198636813d5f6aa41453398c4/raw/4bafb00b511256ab78c259238bdb50a6ab01dc89/DHBB%2520Neudo%2520Ribeiro%2520Campos
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7247 (7.1K) [text/plain]
# Saving to: ‘dhbb.txt’
#
# dhbb.txt            100%[===================>]   7.08K  --.-KB/s    in 0.001s
#
# 2025-05-05 19:21:33 (13.5 MB/s) - ‘dhbb.txt’ saved [7247/7247]

# %%
with open("dhbb.txt") as f:
    texto = f.read()

# %%
print(texto)
# Out:
# «Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima.
# Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente. Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará. Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil.
#
# Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República. Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB). Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito. Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor.
#
# Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha. Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB).
#
# Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra. No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta.
#
# No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta. Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe.
#
# No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração. As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos. O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos. Ao receber o dinheiro, devolvia-o para os contraparentes do governador.
#
# Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição. O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima. De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador.
#
# Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima. Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge. Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado. Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo.
#
# Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz.
#
# A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores. Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição. Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL). Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP).
#
# De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007). Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP. Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia.
#
# Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos.

# %% [markdown]
# # Sentenciando manualmente

# %%
texto = texto.replace("\n", " ")
texto = texto.replace("  ", " ")
texto = texto.replace("", "")

# %%
texto
# Out:
# '«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima. Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente. Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará. Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil. Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República. Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB). Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito. Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor. Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha. Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB). Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra. No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta. No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta. Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe. No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração. As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos. O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos. Ao receber o dinheiro, devolvia-o para os contraparentes do governador. Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição. O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular  ...

# %%
frases = texto.split(".")

# %%
frases
# Out:
# ['«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima',
#  ' Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente',
#  ' Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará',
#  ' Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil',
#  ' Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República',
#  ' Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB)',
#  ' Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito',
#  ' Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor',
#  ' Em julho de 1995, em artigo publicado no jornal «O Estado de S',
#  ' Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha',
#  ' Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB)',
#  ' Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra',
#  ' No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta',
#  ' No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta',
#  ' Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe',
#  ' No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração',
#  ' As denúncias, veiculadas por Ronald Jorge P',
#  ' Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos',
#  ' O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos',
#  ' Ao receber o dinheiro, devolvia-o para os contraparentes do governador',
#  ' Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição',
#  ' O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima',
#  ' De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador',
#  ' Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima',
#  ' Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge',
#  ' Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado',
#  ' Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo',
#  ' Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz',
#  ' A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores',
#  ' Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição',
#  ' Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL)',
#  ' Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP)',
#  ' De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007)',
#  ' Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP',
#  ' Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia',
#  ' Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos',
#  '']

# %%
frases = [frase.strip() + "." for frase in frases if frase]

# %%
frases
# Out:
# ['«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima.',
#  'Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente.',
#  'Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará.',
#  'Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil.',
#  'Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República.',
#  'Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB).',
#  'Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito.',
#  'Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor.',
#  'Em julho de 1995, em artigo publicado no jornal «O Estado de S.',
#  'Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha.',
#  'Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB).',
#  'Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra.',
#  'No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta.',
#  'No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta.',
#  'Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe.',
#  'No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração.',
#  'As denúncias, veiculadas por Ronald Jorge P.',
#  'Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos.',
#  'O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos.',
#  'Ao receber o dinheiro, devolvia-o para os contraparentes do governador.',
#  'Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição.',
#  'O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima.',
#  'De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador.',
#  'Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima.',
#  'Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge.',
#  'Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado.',
#  'Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo.',
#  'Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz.',
#  'A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores.',
#  'Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição.',
#  'Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL).',
#  'Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP).',
#  'De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007).',
#  'Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP.',
#  'Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia.',
#  'Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos.']

# %% [markdown]
# # Sentenciando usando o NLTK

# %%
import nltk

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
texto
# Out:
# '«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima. Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente. Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará. Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil. Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República. Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB). Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito. Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor. Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha. Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB). Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra. No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta. No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta. Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe. No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração. As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos. O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos. Ao receber o dinheiro, devolvia-o para os contraparentes do governador. Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição. O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular  ...

# %%
frases_nltk = nltk.tokenize.sent_tokenize(texto, language="portuguese")

# %%
frases_nltk
# Out:
# ['«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima.',
#  'Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente.',
#  'Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará.',
#  'Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil.',
#  'Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República.',
#  'Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB).',
#  'Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito.',
#  'Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor.',
#  'Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha.',
#  'Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB).',
#  'Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra.',
#  'No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta.',
#  'No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta.',
#  'Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe.',
#  'No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração.',
#  'As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos.',
#  'O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos.',
#  'Ao receber o dinheiro, devolvia-o para os contraparentes do governador.',
#  'Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição.',
#  'O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima.',
#  'De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador.',
#  'Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima.',
#  'Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge.',
#  'Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado.',
#  'Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo.',
#  'Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz.',
#  'A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores.',
#  'Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição.',
#  'Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL).',
#  'Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP).',
#  'De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007).',
#  'Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP.',
#  'Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia.',
#  'Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos.']

# %% [markdown]
# # Vídeo 3: Tokenizando manualmente

# %%
frases_nltk
# Out:
# ['«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima.',
#  'Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente.',
#  'Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará.',
#  'Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil.',
#  'Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República.',
#  'Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB).',
#  'Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito.',
#  'Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor.',
#  'Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha.',
#  'Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB).',
#  'Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra.',
#  'No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta.',
#  'No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta.',
#  'Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe.',
#  'No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração.',
#  'As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos.',
#  'O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos.',
#  'Ao receber o dinheiro, devolvia-o para os contraparentes do governador.',
#  'Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição.',
#  'O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima.',
#  'De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador.',
#  'Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima.',
#  'Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge.',
#  'Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado.',
#  'Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo.',
#  'Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz.',
#  'A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores.',
#  'Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição.',
#  'Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL).',
#  'Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP).',
#  'De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007).',
#  'Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP.',
#  'Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia.',
#  'Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos.']

# %%
frases_tokenizadas = []

for frase in frases_nltk:
    frase = frase.replace(".", " . ")
    frase = frase.replace(",", " , ")
    frase = frase.replace(":", " : ")
    frase = frase.replace("(", " ( ")
    frase = frase.replace(")", " ) ")
    frase = frase.replace("-", " - ")
    frase = frase.replace("«", " « ")
    frase = frase.replace("»", " » ")
    frase = frase.replace("  ", " ")
    frase = frase.strip()
    frases_tokenizadas.append(frase.split(" "))

# %%
frases_tokenizadas
# Out:
# [['«',
#   'Neudo',
#   'Ribeiro',
#   'Campos',
#   '»',
#   'nasceu',
#   'em',
#   'Boa',
#   'Vista',
#   'no',
#   'dia',
#   '1º',
#   'de',
#   'setembro',
#   'de',
#   '1946',
#   ',',
#   'filho',
#   'de',
#   'Antônio',
#   'Ribeiro',
#   'Campos',
#   'e',
#   'de',
#   'América',
#   'Sarmento',
#   'Ribeiro',
#   ',',
#   'família',
#   'tradicional',
#   'na',
#   'política',
#   'de',
#   'Roraima',
#   '.'],
#  ['Concluiu',
#   'os',
#   'cursos',
#   'primário',
#   'e',
#   'ginasial',
#   'em',
#   'sua',
#   'cidade',
#   'natal',
#   'nos',
#   'anos',
#   'de',
#   '1957',
#   'e',
#   '1962',
#   ',',
#   'respectivamente',
#   '.'],
#  ['Após',
#   'uma',
#   'breve',
#   'passagem',
#   'pelo',
#   'Colégio',
#   'Estadual',
#   'do',
#   'Amazonas',
#   ',',
#   'transferiu',
#   '-',
#   'se',
#   'em',
#   '1964',
#   'para',
#   'Belém',
#   ',',
#   'onde',
#   'terminou',
#   'o',
#   'segundo',
#   'grau',
#   'e',
#   'ingressou',
#   'na',
#   'Escola',
#   'de',
#   'Engenharia',
#   'da',
#   'Universidade',
#   'Federal',
#   'do',
#   'Pará',
#   '.'],
#  ['Formou',
#   '-',
#   'se',
#   'em',
#   '1970',
#   'e',
#   'especializou',
#   '-',
#   'se',
#   'na',
#   'área',
#   'de',
#   'tecnologia',
#   'de',
#   'concretos',
#   ',',
#   'tornando',
#   '-',
#   'se',
#   'empresário',
#   'da',
#   'construção',
#   'civil',
#   '.'],
#  ['Em',
#   '1990',
#   ',',
#   'na',
#   'primeira',
#   'eleição',
#   'direta',
#   'para',
#   'governador',
#   'de',
#   'Roraima',
#   'após',
#   'a',
#   'transformação',
#   'do',
#   'antigo',
#   'território',
#   'em',
#   'estado',
#   'pela',
#   'Constituição',
#   'de',
#   '1988',
#   ',',
#   'foi',
#   'lançado',
#   'candidato',
#   'pelo',
#   'Partido',
#   'da',
#   'Reconstrução',
#   'Nacional',
#   '(',
#   'PRN',
#   ')',
#   ',',
#   'que',
#   ',',
#   'em',
#   'dezembro',
#   'de',
#   '1989',
#   ',',
#   'elegera',
#   'Fernando',
#   'Collor',
#   'de',
#   'Melo',
#   'presidente',
#   'da',
#   'República',
#   '.'],
#  ['Realizada',
#   'a',
#   'eleição',
#   'em',
#   'outubro',
#   ',',
#   'foi',
#   'derrotado',
#   'por',
#   'Otomar',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'Trabalhista',
#   'Brasileiro',
#   '(',
#   'PTB',
#   ')',
#   '.'],
#  ['Transferindo',
#   '-',
#   'se',
#   'posteriormente',
#   'para',
#   'esse',
#   'partido',
#   ',',
#   'em',
#   'outubro',
#   'de',
#   '1994',
#   'concorreu',
#   'de',
#   'novo',
#   'ao',
#   'governo',
#   'estadual',
#   ',',
#   'dessa',
#   'vez',
#   'com',
#   'êxito',
#   '.'],
#  ['Ao',
#   'tomar',
#   'posse',
#   'em',
#   'janeiro',
#   'de',
#   '1995',
#   ',',
#   'garantiu',
#   'o',
#   'apoio',
#   'do',
#   'seu',
#   'governo',
#   'ao',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'em',
#   'troca',
#   'da',
#   'liberação',
#   'de',
#   'verbas',
#   'para',
#   'a',
#   'construção',
#   'da',
#   'usina',
#   'hidrelétrica',
#   'de',
#   'Cotingo',
#   'e',
#   'de',
#   'ajuda',
#   'financeira',
#   'para',
#   'dar',
#   'continuidade',
#   'às',
#   'obras',
#   'iniciadas',
#   'por',
#   'seu',
#   'antecessor',
#   '.'],
#  ['Em',
#   'julho',
#   'de',
#   '1995',
#   ',',
#   'em',
#   'artigo',
#   'publicado',
#   'no',
#   'jornal',
#   '«',
#   'O',
#   'Estado',
#   'de',
#   'S',
#   '.',
#   'Paulo',
#   '»',
#   ',',
#   'manifestou',
#   '-',
#   'se',
#   'contrário',
#   'à',
#   'proposta',
#   'de',
#   'diminuição',
#   'do',
#   'número',
#   'de',
#   'parlamentares',
#   'apresentada',
#   'pelo',
#   'deputado',
#   'José',
#   'Genoíno',
#   ',',
#   'do',
#   'Partido',
#   'dos',
#   'Trabalhadores',
#   '(',
#   'PT',
#   ')',
#   ',',
#   'que',
#   'resultaria',
#   'em',
#   'perda',
#   'de',
#   'representação',
#   'para',
#   'os',
#   'estados',
#   'nortistas',
#   ',',
#   'apontando',
#   '-',
#   'a',
#   'como',
#   'demonstrativa',
#   'de',
#   'uma',
#   'visão',
#   'caolha',
#   '.'],
#  ['Contestou',
#   'a',
#   'afirmação',
#   'de',
#   'Genoíno',
#   'de',
#   'que',
#   'haveria',
#   'apenas',
#   'políticos',
#   'conservadores',
#   'e',
#   'clientelistas',
#   'nos',
#   'estados',
#   'do',
#   'Norte',
#   ',',
#   'citando',
#   'como',
#   'exemplo',
#   'de',
#   'bancadas',
#   'de',
#   'esquerda',
#   'expressivas',
#   'a',
#   'do',
#   'Acre',
#   ',',
#   'que',
#   'incluía',
#   'uma',
#   'senadora',
#   'filiada',
#   'ao',
#   'PT',
#   ',',
#   'e',
#   'a',
#   'do',
#   'Amapá',
#   ',',
#   'cujo',
#   'governador',
#   'era',
#   'filiado',
#   'ao',
#   'Partido',
#   'Socialista',
#   'Brasileiro',
#   '(',
#   'PSB',
#   ')',
#   '.'],
#  ['Em',
#   'setembro',
#   'de',
#   '1995',
#   ',',
#   'admitiu',
#   'que',
#   'Roraima',
#   ',',
#   'sete',
#   'anos',
#   'depois',
#   'de',
#   'se',
#   'tornar',
#   'estado',
#   ',',
#   'ainda',
#   'vivia',
#   'à',
#   'custa',
#   'da',
#   'União',
#   ',',
#   'ao',
#   'afirmar',
#   ':',
#   'Sem',
#   'as',
#   'verbas',
#   'federais',
#   ',',
#   'o',
#   'estado',
#   'quebra',
#   '.'],
#  ['No',
#   'mesmo',
#   'mês',
#   ',',
#   'anunciou',
#   'o',
#   'investimento',
#   'de',
#   '15',
#   'milhões',
#   'de',
#   'reais',
#   'para',
#   'asfaltar',
#   'a',
#   'BR',
#   '-',
#   '174',
#   'até',
#   'a',
#   'fronteira',
#   'com',
#   'o',
#   'Amazonas',
#   ',',
#   'obra',
#   'fundamental',
#   ',',
#   'do',
#   'seu',
#   'ponto',
#   'de',
#   'vista',
#   ',',
#   'para',
#   'transformar',
#   'Roraima',
#   'num',
#   'grande',
#   'corredor',
#   'de',
#   'exportação',
#   'rumo',
#   'aos',
#   'mercados',
#   'do',
#   'Caribe',
#   'e',
#   'do',
#   'Nafta',
#   '.'],
#  ['No',
#   'final',
#   'de',
#   'janeiro',
#   'de',
#   '1998',
#   ',',
#   'decretou',
#   'estado',
#   'de',
#   'calamidade',
#   'pública',
#   'em',
#   'Roraima',
#   'devido',
#   'à',
#   'seca',
#   'prolongada',
#   'e',
#   'à',
#   'falta',
#   'de',
#   'água',
#   'potável',
#   ',',
#   'situação',
#   'que',
#   'levaria',
#   'o',
#   'estado',
#   'a',
#   'enfrentar',
#   'um',
#   'dos',
#   'piores',
#   'incêndios',
#   'de',
#   'sua',
#   'história',
#   'durante',
#   'três',
#   'meses',
#   ',',
#   'causando',
#   'a',
#   'devastação',
#   'de',
#   'quase',
#   'dez',
#   'mil',
#   'metros',
#   'quadrados',
#   'de',
#   'floresta',
#   '.'],
#  ['Como',
#   'o',
#   'auxílio',
#   'do',
#   'governo',
#   'federal',
#   'só',
#   'chegou',
#   'em',
#   'meados',
#   'de',
#   'março',
#   ',',
#   'criticou',
#   'o',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'por',
#   'não',
#   'tê',
#   '-',
#   'lo',
#   'ajudado',
#   'desde',
#   'o',
#   'início',
#   'a',
#   'combater',
#   'a',
#   'catástrofe',
#   '.'],
#  ['No',
#   'mês',
#   'de',
#   'junho',
#   ',',
#   'veio',
#   'à',
#   'tona',
#   'um',
#   'amplo',
#   'esquema',
#   'de',
#   'corrupção',
#   'montado',
#   'no',
#   'interior',
#   'da',
#   'Companhia',
#   'de',
#   'Desenvolvimento',
#   'de',
#   'Roraima',
#   '(',
#   'Condesaima',
#   ')',
#   'desde',
#   'o',
#   'início',
#   'de',
#   'sua',
#   'administração',
#   '.'],
#  ['As',
#   'denúncias',
#   ',',
#   'veiculadas',
#   'por',
#   'Ronald',
#   'Jorge',
#   'P',
#   '.',
#   'Santos',
#   'Filho',
#   '-',
#   'um',
#   'dos',
#   'envolvidos',
#   'na',
#   'trama',
#   'e',
#   'que',
#   'assim',
#   'agiu',
#   'por',
#   'sentir',
#   '-',
#   'se',
#   'traído',
#   '-',
#   ',',
#   'incriminavam',
#   'diretamente',
#   'dois',
#   'concunhados',
#   'do',
#   'governador',
#   ',',
#   'que',
#   'teriam',
#   'criado',
#   'uma',
#   'empresa',
#   '-',
#   'fantasma',
#   'supostamente',
#   'destinada',
#   'a',
#   'fornecer',
#   'produtos',
#   'à',
#   'Condesaima',
#   'e',
#   'outros',
#   'órgãos',
#   'públicos',
#   '.'],
#  ['O',
#   'testa',
#   '-',
#   'de',
#   '-',
#   'ferro',
#   'seria',
#   'Ronald',
#   'Jorge',
#   ',',
#   'que',
#   'apresentava',
#   'notas',
#   'fiscais',
#   'frias',
#   'como',
#   'se',
#   'estivesse',
#   'realmente',
#   'fornecendo',
#   'os',
#   'produtos',
#   '.'],
#  ['Ao',
#   'receber',
#   'o',
#   'dinheiro',
#   ',',
#   'devolvia',
#   '-',
#   'o',
#   'para',
#   'os',
#   'contraparentes',
#   'do',
#   'governador',
#   '.'],
#  ['Em',
#   'setembro',
#   ',',
#   'o',
#   'jornal',
#   '«',
#   'O',
#   'Globo',
#   '»',
#   'divulgou',
#   'matéria',
#   'revelando',
#   'a',
#   'existência',
#   'de',
#   'um',
#   'conjunto',
#   'de',
#   'fitas',
#   'contendo',
#   'gravações',
#   'de',
#   'conversas',
#   'de',
#   'Neudo',
#   'Campos',
#   ',',
#   'que',
#   'serviria',
#   'de',
#   'base',
#   'para',
#   'a',
#   'denúncia',
#   'de',
#   'desvio',
#   'de',
#   'recursos',
#   'de',
#   'órgãos',
#   'estatais',
#   'para',
#   'sua',
#   'campanha',
#   'à',
#   'reeleição',
#   '.'],
#  ['O',
#   'teor',
#   'das',
#   'conversas',
#   'comprometia',
#   'o',
#   'secretário',
#   'de',
#   'Fazenda',
#   ',',
#   'Roberto',
#   'Leonel;',
#   'a',
#   'chefe',
#   'do',
#   'Gabinete',
#   'Civil',
#   ',',
#   'Cilene',
#   'Salomão',
#   ',',
#   'acusada',
#   'de',
#   'articular',
#   'operações',
#   'de',
#   'triangulação',
#   'e',
#   'distribuição',
#   'de',
#   'recursos',
#   'para',
#   'a',
#   'campanha;',
#   'e',
#   'parentes',
#   'do',
#   'governador',
#   'que',
#   'ocupavam',
#   'cargos',
#   'de',
#   'direção',
#   'na',
#   'Condesaima',
#   '.'],
#  ['De',
#   'acordo',
#   'com',
#   'as',
#   'gravações',
#   ',',
#   'o',
#   'dinheiro',
#   'era',
#   'desviado',
#   'da',
#   'Secretaria',
#   'de',
#   'Fazenda',
#   'e',
#   'repassado',
#   'para',
#   'a',
#   'Condesaima',
#   ',',
#   'que',
#   'por',
#   'sua',
#   'vez',
#   'tinha',
#   'a',
#   'incumbência',
#   'de',
#   'entregar',
#   'os',
#   'pacotes',
#   'com',
#   'as',
#   'cédulas',
#   'para',
#   'assessores',
#   'do',
#   'governador',
#   '.'],
#  ['Durante',
#   'as',
#   'investigações',
#   ',',
#   'o',
#   'juiz',
#   'de',
#   'primeira',
#   'inst"ncia',
#   'Hélder',
#   'Girão',
#   'Barreto',
#   'julgou',
#   'procedente',
#   'uma',
#   'ação',
#   'popular',
#   'requerendo',
#   'a',
#   'demissão',
#   'de',
#   '17',
#   'parentes',
#   'do',
#   'governador',
#   ',',
#   'sob',
#   'a',
#   'acusação',
#   'de',
#   'desviarem',
#   'recursos',
#   'públicos',
#   'para',
#   'a',
#   'campanha',
#   'e',
#   'de',
#   'criarem',
#   'empresas',
#   '-',
#   'fantasmas',
#   'para',
#   'fornecer',
#   'suprimentos',
#   'à',
#   'Condesaima',
#   ',',
#   'e',
#   'determinou',
#   'ainda',
#   'a',
#   'demissão',
#   'de',
#   'todos',
#   'os',
#   'parentes',
#   'dos',
#   'desembargadores',
#   'que',
#   'lotavam',
#   'o',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   '.'],
#  ['Além',
#   'disso',
#   ',',
#   'deu',
#   'parecer',
#   'favorável',
#   'ao',
#   'pedido',
#   'de',
#   'quebra',
#   'de',
#   'sigilo',
#   'bancário',
#   'de',
#   'oito',
#   'auxiliares',
#   'do',
#   'governador',
#   'que',
#   'estariam',
#   'na',
#   'ponta',
#   'do',
#   'esquema',
#   'de',
#   'corrupção',
#   'denunciado',
#   'por',
#   'Ronald',
#   'Jorge',
#   '.'],
#  ['Como',
#   'resultado',
#   'de',
#   'sua',
#   'decisão',
#   ',',
#   'além',
#   'de',
#   'ser',
#   'afastado',
#   'das',
#   'funções',
#   'que',
#   'exercia',
#   'e',
#   'de',
#   'ser',
#   'alvo',
#   'de',
#   'um',
#   'processo',
#   'administrativo',
#   'por',
#   'supostas',
#   'faltas',
#   'disciplinares',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'teve',
#   'todas',
#   'as',
#   'suas',
#   'decisões',
#   'cassadas',
#   'pelo',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'do',
#   'estado',
#   '.'],
#  ['Os',
#   'parentes',
#   'acusados',
#   'do',
#   'governador',
#   'só',
#   'foram',
#   'demitidos',
#   'devido',
#   'às',
#   'proporções',
#   'atingidas',
#   'pelo',
#   'esc"ndalo',
#   '.'],
#  ['Por',
#   'conta',
#   'disso',
#   ',',
#   'o',
#   'Supremo',
#   'Tribunal',
#   'Federal',
#   '(',
#   'STF',
#   ')',
#   'acabou',
#   'por',
#   'intervir',
#   'no',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   ',',
#   'suspeito',
#   'de',
#   'tentar',
#   'obstruir',
#   'a',
#   'investigação',
#   'das',
#   'denúncias',
#   'de',
#   'corrupção',
#   'e',
#   'nepotismo',
#   'contra',
#   'o',
#   'governador',
#   ',',
#   'e',
#   'por',
#   'reintegrar',
#   ',',
#   'por',
#   'unanimidade',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   ',',
#   'ao',
#   'decidir',
#   'que',
#   'cinco',
#   'dos',
#   'seis',
#   'desembargadores',
#   'daquela',
#   'corte',
#   'estavam',
#   'impedidos',
#   'de',
#   'julgar',
#   'o',
#   'mandado',
#   'de',
#   'segurança',
#   'por',
#   'ele',
#   'impetrado',
#   ',',
#   'já',
#   'que',
#   'haviam',
#   'tido',
#   'parentes',
#   'demitidos',
#   'do',
#   'tribunal',
#   'por',
#   'decisão',
#   'do',
#   'juiz',
#   '.'],
#  ['A',
#   'despeito',
#   'de',
#   'tais',
#   'denúncias',
#   ',',
#   'Neudo',
#   'Campos',
#   'disputou',
#   'com',
#   'êxito',
#   'a',
#   'reeleição',
#   'em',
#   'outubro',
#   'de',
#   '1998',
#   ',',
#   'à',
#   'frente',
#   'de',
#   'coligação',
#   'integrada',
#   'por',
#   'seu',
#   'partido',
#   ',',
#   'o',
#   'Partido',
#   'Progressista',
#   'Brasileiro',
#   '(',
#   'PPB',
#   ')',
#   ',',
#   'e',
#   'ainda',
#   'pelo',
#   'Partido',
#   'Liberal',
#   '(',
#   'PL',
#   ')',
#   'e',
#   'o',
#   'Partido',
#   'Democrático',
#   'Trabalhista',
#   '(',
#   'PDT',
#   ')',
#   ',',
#   'além',
#   'de',
#   'agremiações',
#   'menores',
#   '.'],
#  ['Teve',
#   'como',
#   'principais',
#   'adversárias',
#   'a',
#   'ex',
#   '-',
#   'prefeita',
#   'de',
#   'Boa',
#   'Vista',
#   'Teresa',
#   'Jucá',
#   'e',
#   'a',
#   'senadora',
#   'Marluce',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'do',
#   'Movimento',
#   'Democrático',
#   'Brasileiro',
#   '(',
#   'PMDB',
#   ')',
#   ',',
#   'com',
#   'cujo',
#   'marido',
#   ',',
#   'Otomar',
#   'Pinto',
#   ',',
#   'prefeito',
#   'de',
#   'Boa',
#   'Vista',
#   ',',
#   'rompeu',
#   'depois',
#   'que',
#   'decidiu',
#   'concorrer',
#   'à',
#   'reeleição',
#   '.'],
#  ['Iniciou',
#   'seu',
#   'segundo',
#   'governo',
#   'em',
#   '1º',
#   'de',
#   'janeiro',
#   'de',
#   '1999',
#   ',',
#   'e',
#   'em',
#   '2000',
#   'deixou',
#   'o',
#   'PPB',
#   'e',
#   'filiou',
#   '-',
#   'se',
#   'ao',
#   'Partido',
#   'da',
#   'Frente',
#   'Liberal',
#   '(',
#   'PFL',
#   ')',
#   '.'],
#  ['Em',
#   'janeiro',
#   'de',
#   '2003',
#   'encerrou',
#   'o',
#   'governo',
#   ',',
#   'deixou',
#   'o',
#   'PFL',
#   'e',
#   'filiou',
#   '-',
#   'se',
#   'ao',
#   'Partido',
#   'Progressista',
#   '(',
#   'PP',
#   ')',
#   '.'],
#  ['De',
#   '2005',
#   'a',
#   '2006',
#   ',',
#   'foi',
#   'secretário',
#   'de',
#   'Governo',
#   'de',
#   'Roraima',
#   ',',
#   'na',
#   'gestão',
#   'de',
#   'Otomar',
#   'Pinto',
#   '(',
#   '2004',
#   '-',
#   '2007',
#   ')',
#   '.'],
#  ['Nesse',
#   'último',
#   'ano',
#   'concorreu',
#   'com',
#   'êxito',
#   'às',
#   'eleições',
#   'para',
#   'deputado',
#   'federal',
#   'na',
#   'legenda',
#   'do',
#   'PP',
#   '.'],
#  ['Assumindo',
#   'o',
#   'mandato',
#   'na',
#   'C"mara',
#   'em',
#   'fevereiro',
#   'de',
#   '2007',
#   ',',
#   'tornou',
#   '-',
#   'se',
#   'membro',
#   'titular',
#   'das',
#   'comissões',
#   'da',
#   'Amazônia',
#   ',',
#   'Integração',
#   'Nacional',
#   'e',
#   'de',
#   'Desenvolvimento',
#   'Regional',
#   ',',
#   'e',
#   'de',
#   'Minas',
#   'e',
#   'Energia',
#   '.'],
#  ['Casou',
#   '-',
#   'se',
#   'com',
#   'Sueli',
#   'Campos',
#   ',',
#   'deputada',
#   'federal',
#   'por',
#   'Roraima',
#   'de',
#   '2003',
#   'a',
#   '2007',
#   ',',
#   'e',
#   'vice',
#   '-',
#   'prefeita',
#   'de',
#   'Rio',
#   'Branco',
#   'a',
#   'partir',
#   'de',
#   '2009',
#   ',',
#   'com',
#   'quem',
#   'teve',
#   'quatro',
#   'filhos',
#   '.']]

# %%
frases_tokenizadas[8]
# Out:
# ['Em',
#  'julho',
#  'de',
#  '1995',
#  ',',
#  'em',
#  'artigo',
#  'publicado',
#  'no',
#  'jornal',
#  '«',
#  'O',
#  'Estado',
#  'de',
#  'S',
#  '.',
#  'Paulo',
#  '»',
#  ',',
#  'manifestou',
#  '-',
#  'se',
#  'contrário',
#  'à',
#  'proposta',
#  'de',
#  'diminuição',
#  'do',
#  'número',
#  'de',
#  'parlamentares',
#  'apresentada',
#  'pelo',
#  'deputado',
#  'José',
#  'Genoíno',
#  ',',
#  'do',
#  'Partido',
#  'dos',
#  'Trabalhadores',
#  '(',
#  'PT',
#  ')',
#  ',',
#  'que',
#  'resultaria',
#  'em',
#  'perda',
#  'de',
#  'representação',
#  'para',
#  'os',
#  'estados',
#  'nortistas',
#  ',',
#  'apontando',
#  '-',
#  'a',
#  'como',
#  'demonstrativa',
#  'de',
#  'uma',
#  'visão',
#  'caolha',
#  '.']

# %% [markdown]
# # Tokenizando usando NLTK

# %%
frases_nltk
# Out:
# ['«Neudo Ribeiro Campos» nasceu em Boa Vista no dia 1º de setembro de 1946, filho de Antônio Ribeiro Campos e de América Sarmento Ribeiro, família tradicional na política de Roraima.',
#  'Concluiu os cursos primário e ginasial em sua cidade natal nos anos de 1957 e 1962, respectivamente.',
#  'Após uma breve passagem pelo Colégio Estadual do Amazonas, transferiu-se em 1964 para Belém, onde terminou o segundo grau e ingressou na Escola de Engenharia da Universidade Federal do Pará.',
#  'Formou-se em 1970 e especializou-se na área de tecnologia de concretos, tornando-se empresário da construção civil.',
#  'Em 1990, na primeira eleição direta para governador de Roraima após a transformação do antigo território em estado pela Constituição de 1988, foi lançado candidato pelo Partido da Reconstrução Nacional (PRN), que, em dezembro de 1989, elegera Fernando Collor de Melo presidente da República.',
#  'Realizada a eleição em outubro, foi derrotado por Otomar Pinto, do Partido Trabalhista Brasileiro (PTB).',
#  'Transferindo-se posteriormente para esse partido, em outubro de 1994 concorreu de novo ao governo estadual, dessa vez com êxito.',
#  'Ao tomar posse em janeiro de 1995, garantiu o apoio do seu governo ao presidente Fernando Henrique Cardoso em troca da liberação de verbas para a construção da usina hidrelétrica de Cotingo e de ajuda financeira para dar continuidade às obras iniciadas por seu antecessor.',
#  'Em julho de 1995, em artigo publicado no jornal «O Estado de S. Paulo», manifestou-se contrário à proposta de diminuição do número de parlamentares apresentada pelo deputado José Genoíno, do Partido dos Trabalhadores (PT), que resultaria em perda de representação para os estados nortistas, apontando-a como demonstrativa de uma visão caolha.',
#  'Contestou a afirmação de Genoíno de que haveria apenas políticos conservadores e clientelistas nos estados do Norte, citando como exemplo de bancadas de esquerda expressivas a do Acre, que incluía uma senadora filiada ao PT, e a do Amapá, cujo governador era filiado ao Partido Socialista Brasileiro (PSB).',
#  'Em setembro de 1995, admitiu que Roraima, sete anos depois de se tornar estado, ainda vivia à custa da União, ao afirmar: Sem as verbas federais, o estado quebra.',
#  'No mesmo mês, anunciou o investimento de 15 milhões de reais para asfaltar a BR-174 até a fronteira com o Amazonas, obra fundamental, do seu ponto de vista, para transformar Roraima num grande corredor de exportação rumo aos mercados do Caribe e do Nafta.',
#  'No final de janeiro de 1998, decretou estado de calamidade pública em Roraima devido à seca prolongada e à falta de água potável, situação que levaria o estado a enfrentar um dos piores incêndios de sua história durante três meses, causando a devastação de quase dez mil metros quadrados de floresta.',
#  'Como o auxílio do governo federal só chegou em meados de março, criticou o presidente Fernando Henrique Cardoso por não tê-lo ajudado desde o início a combater a catástrofe.',
#  'No mês de junho, veio à tona um amplo esquema de corrupção montado no interior da Companhia de Desenvolvimento de Roraima (Condesaima) desde o início de sua administração.',
#  'As denúncias, veiculadas por Ronald Jorge P. Santos Filho - um dos envolvidos na trama e que assim agiu por sentir-se traído -, incriminavam diretamente dois concunhados do governador, que teriam criado uma empresa-fantasma supostamente destinada a fornecer produtos à Condesaima e outros órgãos públicos.',
#  'O testa-de-ferro seria Ronald Jorge, que apresentava notas fiscais frias como se estivesse realmente fornecendo os produtos.',
#  'Ao receber o dinheiro, devolvia-o para os contraparentes do governador.',
#  'Em setembro, o jornal «O Globo» divulgou matéria revelando a existência de um conjunto de fitas contendo gravações de conversas de Neudo Campos, que serviria de base para a denúncia de desvio de recursos de órgãos estatais para sua campanha à reeleição.',
#  'O teor das conversas comprometia o secretário de Fazenda, Roberto Leonel; a chefe do Gabinete Civil, Cilene Salomão, acusada de articular operações de triangulação e distribuição de recursos para a campanha; e parentes do governador que ocupavam cargos de direção na Condesaima.',
#  'De acordo com as gravações, o dinheiro era desviado da Secretaria de Fazenda e repassado para a Condesaima, que por sua vez tinha a incumbência de entregar os pacotes com as cédulas para assessores do governador.',
#  'Durante as investigações, o juiz de primeira inst"ncia Hélder Girão Barreto julgou procedente uma ação popular requerendo a demissão de 17 parentes do governador, sob a acusação de desviarem recursos públicos para a campanha e de criarem empresas-fantasmas para fornecer suprimentos à Condesaima, e determinou ainda a demissão de todos os parentes dos desembargadores que lotavam o Tribunal de Justiça de Roraima.',
#  'Além disso, deu parecer favorável ao pedido de quebra de sigilo bancário de oito auxiliares do governador que estariam na ponta do esquema de corrupção denunciado por Ronald Jorge.',
#  'Como resultado de sua decisão, além de ser afastado das funções que exercia e de ser alvo de um processo administrativo por supostas faltas disciplinares, o juiz Hélder Barreto teve todas as suas decisões cassadas pelo Tribunal de Justiça do estado.',
#  'Os parentes acusados do governador só foram demitidos devido às proporções atingidas pelo esc"ndalo.',
#  'Por conta disso, o Supremo Tribunal Federal (STF) acabou por intervir no Tribunal de Justiça de Roraima, suspeito de tentar obstruir a investigação das denúncias de corrupção e nepotismo contra o governador, e por reintegrar, por unanimidade, o juiz Hélder Barreto, ao decidir que cinco dos seis desembargadores daquela corte estavam impedidos de julgar o mandado de segurança por ele impetrado, já que haviam tido parentes demitidos do tribunal por decisão do juiz.',
#  'A despeito de tais denúncias, Neudo Campos disputou com êxito a reeleição em outubro de 1998, à frente de coligação integrada por seu partido, o Partido Progressista Brasileiro (PPB), e ainda pelo Partido Liberal (PL) e o Partido Democrático Trabalhista (PDT), além de agremiações menores.',
#  'Teve como principais adversárias a ex-prefeita de Boa Vista Teresa Jucá e a senadora Marluce Pinto, do Partido do Movimento Democrático Brasileiro (PMDB), com cujo marido, Otomar Pinto, prefeito de Boa Vista, rompeu depois que decidiu concorrer à reeleição.',
#  'Iniciou seu segundo governo em 1º de janeiro de 1999, e em 2000 deixou o PPB e filiou-se ao Partido da Frente Liberal (PFL).',
#  'Em janeiro de 2003 encerrou o governo, deixou o PFL e filiou-se ao Partido Progressista (PP).',
#  'De 2005 a 2006, foi secretário de Governo de Roraima, na gestão de Otomar Pinto (2004-2007).',
#  'Nesse último ano concorreu com êxito às eleições para deputado federal na legenda do PP.',
#  'Assumindo o mandato na C"mara em fevereiro de 2007, tornou-se membro titular das comissões da Amazônia, Integração Nacional e de Desenvolvimento Regional, e de Minas e Energia.',
#  'Casou-se com Sueli Campos, deputada federal por Roraima de 2003 a 2007, e vice-prefeita de Rio Branco a partir de 2009, com quem teve quatro filhos.']

# %%
frases_tokenizadas_nltk = []

for frase in frases_nltk:
    frase = nltk.tokenize.word_tokenize(frase)
    frases_tokenizadas_nltk.append(frase)

# %%
frases_tokenizadas_nltk
# Out:
# [['«',
#   'Neudo',
#   'Ribeiro',
#   'Campos',
#   '»',
#   'nasceu',
#   'em',
#   'Boa',
#   'Vista',
#   'no',
#   'dia',
#   '1º',
#   'de',
#   'setembro',
#   'de',
#   '1946',
#   ',',
#   'filho',
#   'de',
#   'Antônio',
#   'Ribeiro',
#   'Campos',
#   'e',
#   'de',
#   'América',
#   'Sarmento',
#   'Ribeiro',
#   ',',
#   'família',
#   'tradicional',
#   'na',
#   'política',
#   'de',
#   'Roraima',
#   '.'],
#  ['Concluiu',
#   'os',
#   'cursos',
#   'primário',
#   'e',
#   'ginasial',
#   'em',
#   'sua',
#   'cidade',
#   'natal',
#   'nos',
#   'anos',
#   'de',
#   '1957',
#   'e',
#   '1962',
#   ',',
#   'respectivamente',
#   '.'],
#  ['Após',
#   'uma',
#   'breve',
#   'passagem',
#   'pelo',
#   'Colégio',
#   'Estadual',
#   'do',
#   'Amazonas',
#   ',',
#   'transferiu-se',
#   'em',
#   '1964',
#   'para',
#   'Belém',
#   ',',
#   'onde',
#   'terminou',
#   'o',
#   'segundo',
#   'grau',
#   'e',
#   'ingressou',
#   'na',
#   'Escola',
#   'de',
#   'Engenharia',
#   'da',
#   'Universidade',
#   'Federal',
#   'do',
#   'Pará',
#   '.'],
#  ['Formou-se',
#   'em',
#   '1970',
#   'e',
#   'especializou-se',
#   'na',
#   'área',
#   'de',
#   'tecnologia',
#   'de',
#   'concretos',
#   ',',
#   'tornando-se',
#   'empresário',
#   'da',
#   'construção',
#   'civil',
#   '.'],
#  ['Em',
#   '1990',
#   ',',
#   'na',
#   'primeira',
#   'eleição',
#   'direta',
#   'para',
#   'governador',
#   'de',
#   'Roraima',
#   'após',
#   'a',
#   'transformação',
#   'do',
#   'antigo',
#   'território',
#   'em',
#   'estado',
#   'pela',
#   'Constituição',
#   'de',
#   '1988',
#   ',',
#   'foi',
#   'lançado',
#   'candidato',
#   'pelo',
#   'Partido',
#   'da',
#   'Reconstrução',
#   'Nacional',
#   '(',
#   'PRN',
#   ')',
#   ',',
#   'que',
#   ',',
#   'em',
#   'dezembro',
#   'de',
#   '1989',
#   ',',
#   'elegera',
#   'Fernando',
#   'Collor',
#   'de',
#   'Melo',
#   'presidente',
#   'da',
#   'República',
#   '.'],
#  ['Realizada',
#   'a',
#   'eleição',
#   'em',
#   'outubro',
#   ',',
#   'foi',
#   'derrotado',
#   'por',
#   'Otomar',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'Trabalhista',
#   'Brasileiro',
#   '(',
#   'PTB',
#   ')',
#   '.'],
#  ['Transferindo-se',
#   'posteriormente',
#   'para',
#   'esse',
#   'partido',
#   ',',
#   'em',
#   'outubro',
#   'de',
#   '1994',
#   'concorreu',
#   'de',
#   'novo',
#   'ao',
#   'governo',
#   'estadual',
#   ',',
#   'dessa',
#   'vez',
#   'com',
#   'êxito',
#   '.'],
#  ['Ao',
#   'tomar',
#   'posse',
#   'em',
#   'janeiro',
#   'de',
#   '1995',
#   ',',
#   'garantiu',
#   'o',
#   'apoio',
#   'do',
#   'seu',
#   'governo',
#   'ao',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'em',
#   'troca',
#   'da',
#   'liberação',
#   'de',
#   'verbas',
#   'para',
#   'a',
#   'construção',
#   'da',
#   'usina',
#   'hidrelétrica',
#   'de',
#   'Cotingo',
#   'e',
#   'de',
#   'ajuda',
#   'financeira',
#   'para',
#   'dar',
#   'continuidade',
#   'às',
#   'obras',
#   'iniciadas',
#   'por',
#   'seu',
#   'antecessor',
#   '.'],
#  ['Em',
#   'julho',
#   'de',
#   '1995',
#   ',',
#   'em',
#   'artigo',
#   'publicado',
#   'no',
#   'jornal',
#   '«',
#   'O',
#   'Estado',
#   'de',
#   'S.',
#   'Paulo',
#   '»',
#   ',',
#   'manifestou-se',
#   'contrário',
#   'à',
#   'proposta',
#   'de',
#   'diminuição',
#   'do',
#   'número',
#   'de',
#   'parlamentares',
#   'apresentada',
#   'pelo',
#   'deputado',
#   'José',
#   'Genoíno',
#   ',',
#   'do',
#   'Partido',
#   'dos',
#   'Trabalhadores',
#   '(',
#   'PT',
#   ')',
#   ',',
#   'que',
#   'resultaria',
#   'em',
#   'perda',
#   'de',
#   'representação',
#   'para',
#   'os',
#   'estados',
#   'nortistas',
#   ',',
#   'apontando-a',
#   'como',
#   'demonstrativa',
#   'de',
#   'uma',
#   'visão',
#   'caolha',
#   '.'],
#  ['Contestou',
#   'a',
#   'afirmação',
#   'de',
#   'Genoíno',
#   'de',
#   'que',
#   'haveria',
#   'apenas',
#   'políticos',
#   'conservadores',
#   'e',
#   'clientelistas',
#   'nos',
#   'estados',
#   'do',
#   'Norte',
#   ',',
#   'citando',
#   'como',
#   'exemplo',
#   'de',
#   'bancadas',
#   'de',
#   'esquerda',
#   'expressivas',
#   'a',
#   'do',
#   'Acre',
#   ',',
#   'que',
#   'incluía',
#   'uma',
#   'senadora',
#   'filiada',
#   'ao',
#   'PT',
#   ',',
#   'e',
#   'a',
#   'do',
#   'Amapá',
#   ',',
#   'cujo',
#   'governador',
#   'era',
#   'filiado',
#   'ao',
#   'Partido',
#   'Socialista',
#   'Brasileiro',
#   '(',
#   'PSB',
#   ')',
#   '.'],
#  ['Em',
#   'setembro',
#   'de',
#   '1995',
#   ',',
#   'admitiu',
#   'que',
#   'Roraima',
#   ',',
#   'sete',
#   'anos',
#   'depois',
#   'de',
#   'se',
#   'tornar',
#   'estado',
#   ',',
#   'ainda',
#   'vivia',
#   'à',
#   'custa',
#   'da',
#   'União',
#   ',',
#   'ao',
#   'afirmar',
#   ':',
#   'Sem',
#   'as',
#   'verbas',
#   'federais',
#   ',',
#   'o',
#   'estado',
#   'quebra',
#   '.'],
#  ['No',
#   'mesmo',
#   'mês',
#   ',',
#   'anunciou',
#   'o',
#   'investimento',
#   'de',
#   '15',
#   'milhões',
#   'de',
#   'reais',
#   'para',
#   'asfaltar',
#   'a',
#   'BR-174',
#   'até',
#   'a',
#   'fronteira',
#   'com',
#   'o',
#   'Amazonas',
#   ',',
#   'obra',
#   'fundamental',
#   ',',
#   'do',
#   'seu',
#   'ponto',
#   'de',
#   'vista',
#   ',',
#   'para',
#   'transformar',
#   'Roraima',
#   'num',
#   'grande',
#   'corredor',
#   'de',
#   'exportação',
#   'rumo',
#   'aos',
#   'mercados',
#   'do',
#   'Caribe',
#   'e',
#   'do',
#   'Nafta',
#   '.'],
#  ['No',
#   'final',
#   'de',
#   'janeiro',
#   'de',
#   '1998',
#   ',',
#   'decretou',
#   'estado',
#   'de',
#   'calamidade',
#   'pública',
#   'em',
#   'Roraima',
#   'devido',
#   'à',
#   'seca',
#   'prolongada',
#   'e',
#   'à',
#   'falta',
#   'de',
#   'água',
#   'potável',
#   ',',
#   'situação',
#   'que',
#   'levaria',
#   'o',
#   'estado',
#   'a',
#   'enfrentar',
#   'um',
#   'dos',
#   'piores',
#   'incêndios',
#   'de',
#   'sua',
#   'história',
#   'durante',
#   'três',
#   'meses',
#   ',',
#   'causando',
#   'a',
#   'devastação',
#   'de',
#   'quase',
#   'dez',
#   'mil',
#   'metros',
#   'quadrados',
#   'de',
#   'floresta',
#   '.'],
#  ['Como',
#   'o',
#   'auxílio',
#   'do',
#   'governo',
#   'federal',
#   'só',
#   'chegou',
#   'em',
#   'meados',
#   'de',
#   'março',
#   ',',
#   'criticou',
#   'o',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'por',
#   'não',
#   'tê-lo',
#   'ajudado',
#   'desde',
#   'o',
#   'início',
#   'a',
#   'combater',
#   'a',
#   'catástrofe',
#   '.'],
#  ['No',
#   'mês',
#   'de',
#   'junho',
#   ',',
#   'veio',
#   'à',
#   'tona',
#   'um',
#   'amplo',
#   'esquema',
#   'de',
#   'corrupção',
#   'montado',
#   'no',
#   'interior',
#   'da',
#   'Companhia',
#   'de',
#   'Desenvolvimento',
#   'de',
#   'Roraima',
#   '(',
#   'Condesaima',
#   ')',
#   'desde',
#   'o',
#   'início',
#   'de',
#   'sua',
#   'administração',
#   '.'],
#  ['As',
#   'denúncias',
#   ',',
#   'veiculadas',
#   'por',
#   'Ronald',
#   'Jorge',
#   'P.',
#   'Santos',
#   'Filho',
#   '-',
#   'um',
#   'dos',
#   'envolvidos',
#   'na',
#   'trama',
#   'e',
#   'que',
#   'assim',
#   'agiu',
#   'por',
#   'sentir-se',
#   'traído',
#   '-',
#   ',',
#   'incriminavam',
#   'diretamente',
#   'dois',
#   'concunhados',
#   'do',
#   'governador',
#   ',',
#   'que',
#   'teriam',
#   'criado',
#   'uma',
#   'empresa-fantasma',
#   'supostamente',
#   'destinada',
#   'a',
#   'fornecer',
#   'produtos',
#   'à',
#   'Condesaima',
#   'e',
#   'outros',
#   'órgãos',
#   'públicos',
#   '.'],
#  ['O',
#   'testa-de-ferro',
#   'seria',
#   'Ronald',
#   'Jorge',
#   ',',
#   'que',
#   'apresentava',
#   'notas',
#   'fiscais',
#   'frias',
#   'como',
#   'se',
#   'estivesse',
#   'realmente',
#   'fornecendo',
#   'os',
#   'produtos',
#   '.'],
#  ['Ao',
#   'receber',
#   'o',
#   'dinheiro',
#   ',',
#   'devolvia-o',
#   'para',
#   'os',
#   'contraparentes',
#   'do',
#   'governador',
#   '.'],
#  ['Em',
#   'setembro',
#   ',',
#   'o',
#   'jornal',
#   '«',
#   'O',
#   'Globo',
#   '»',
#   'divulgou',
#   'matéria',
#   'revelando',
#   'a',
#   'existência',
#   'de',
#   'um',
#   'conjunto',
#   'de',
#   'fitas',
#   'contendo',
#   'gravações',
#   'de',
#   'conversas',
#   'de',
#   'Neudo',
#   'Campos',
#   ',',
#   'que',
#   'serviria',
#   'de',
#   'base',
#   'para',
#   'a',
#   'denúncia',
#   'de',
#   'desvio',
#   'de',
#   'recursos',
#   'de',
#   'órgãos',
#   'estatais',
#   'para',
#   'sua',
#   'campanha',
#   'à',
#   'reeleição',
#   '.'],
#  ['O',
#   'teor',
#   'das',
#   'conversas',
#   'comprometia',
#   'o',
#   'secretário',
#   'de',
#   'Fazenda',
#   ',',
#   'Roberto',
#   'Leonel',
#   ';',
#   'a',
#   'chefe',
#   'do',
#   'Gabinete',
#   'Civil',
#   ',',
#   'Cilene',
#   'Salomão',
#   ',',
#   'acusada',
#   'de',
#   'articular',
#   'operações',
#   'de',
#   'triangulação',
#   'e',
#   'distribuição',
#   'de',
#   'recursos',
#   'para',
#   'a',
#   'campanha',
#   ';',
#   'e',
#   'parentes',
#   'do',
#   'governador',
#   'que',
#   'ocupavam',
#   'cargos',
#   'de',
#   'direção',
#   'na',
#   'Condesaima',
#   '.'],
#  ['De',
#   'acordo',
#   'com',
#   'as',
#   'gravações',
#   ',',
#   'o',
#   'dinheiro',
#   'era',
#   'desviado',
#   'da',
#   'Secretaria',
#   'de',
#   'Fazenda',
#   'e',
#   'repassado',
#   'para',
#   'a',
#   'Condesaima',
#   ',',
#   'que',
#   'por',
#   'sua',
#   'vez',
#   'tinha',
#   'a',
#   'incumbência',
#   'de',
#   'entregar',
#   'os',
#   'pacotes',
#   'com',
#   'as',
#   'cédulas',
#   'para',
#   'assessores',
#   'do',
#   'governador',
#   '.'],
#  ['Durante',
#   'as',
#   'investigações',
#   ',',
#   'o',
#   'juiz',
#   'de',
#   'primeira',
#   'inst',
#   "''",
#   'ncia',
#   'Hélder',
#   'Girão',
#   'Barreto',
#   'julgou',
#   'procedente',
#   'uma',
#   'ação',
#   'popular',
#   'requerendo',
#   'a',
#   'demissão',
#   'de',
#   '17',
#   'parentes',
#   'do',
#   'governador',
#   ',',
#   'sob',
#   'a',
#   'acusação',
#   'de',
#   'desviarem',
#   'recursos',
#   'públicos',
#   'para',
#   'a',
#   'campanha',
#   'e',
#   'de',
#   'criarem',
#   'empresas-fantasmas',
#   'para',
#   'fornecer',
#   'suprimentos',
#   'à',
#   'Condesaima',
#   ',',
#   'e',
#   'determinou',
#   'ainda',
#   'a',
#   'demissão',
#   'de',
#   'todos',
#   'os',
#   'parentes',
#   'dos',
#   'desembargadores',
#   'que',
#   'lotavam',
#   'o',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   '.'],
#  ['Além',
#   'disso',
#   ',',
#   'deu',
#   'parecer',
#   'favorável',
#   'ao',
#   'pedido',
#   'de',
#   'quebra',
#   'de',
#   'sigilo',
#   'bancário',
#   'de',
#   'oito',
#   'auxiliares',
#   'do',
#   'governador',
#   'que',
#   'estariam',
#   'na',
#   'ponta',
#   'do',
#   'esquema',
#   'de',
#   'corrupção',
#   'denunciado',
#   'por',
#   'Ronald',
#   'Jorge',
#   '.'],
#  ['Como',
#   'resultado',
#   'de',
#   'sua',
#   'decisão',
#   ',',
#   'além',
#   'de',
#   'ser',
#   'afastado',
#   'das',
#   'funções',
#   'que',
#   'exercia',
#   'e',
#   'de',
#   'ser',
#   'alvo',
#   'de',
#   'um',
#   'processo',
#   'administrativo',
#   'por',
#   'supostas',
#   'faltas',
#   'disciplinares',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'teve',
#   'todas',
#   'as',
#   'suas',
#   'decisões',
#   'cassadas',
#   'pelo',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'do',
#   'estado',
#   '.'],
#  ['Os',
#   'parentes',
#   'acusados',
#   'do',
#   'governador',
#   'só',
#   'foram',
#   'demitidos',
#   'devido',
#   'às',
#   'proporções',
#   'atingidas',
#   'pelo',
#   'esc',
#   "''",
#   'ndalo',
#   '.'],
#  ['Por',
#   'conta',
#   'disso',
#   ',',
#   'o',
#   'Supremo',
#   'Tribunal',
#   'Federal',
#   '(',
#   'STF',
#   ')',
#   'acabou',
#   'por',
#   'intervir',
#   'no',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   ',',
#   'suspeito',
#   'de',
#   'tentar',
#   'obstruir',
#   'a',
#   'investigação',
#   'das',
#   'denúncias',
#   'de',
#   'corrupção',
#   'e',
#   'nepotismo',
#   'contra',
#   'o',
#   'governador',
#   ',',
#   'e',
#   'por',
#   'reintegrar',
#   ',',
#   'por',
#   'unanimidade',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   ',',
#   'ao',
#   'decidir',
#   'que',
#   'cinco',
#   'dos',
#   'seis',
#   'desembargadores',
#   'daquela',
#   'corte',
#   'estavam',
#   'impedidos',
#   'de',
#   'julgar',
#   'o',
#   'mandado',
#   'de',
#   'segurança',
#   'por',
#   'ele',
#   'impetrado',
#   ',',
#   'já',
#   'que',
#   'haviam',
#   'tido',
#   'parentes',
#   'demitidos',
#   'do',
#   'tribunal',
#   'por',
#   'decisão',
#   'do',
#   'juiz',
#   '.'],
#  ['A',
#   'despeito',
#   'de',
#   'tais',
#   'denúncias',
#   ',',
#   'Neudo',
#   'Campos',
#   'disputou',
#   'com',
#   'êxito',
#   'a',
#   'reeleição',
#   'em',
#   'outubro',
#   'de',
#   '1998',
#   ',',
#   'à',
#   'frente',
#   'de',
#   'coligação',
#   'integrada',
#   'por',
#   'seu',
#   'partido',
#   ',',
#   'o',
#   'Partido',
#   'Progressista',
#   'Brasileiro',
#   '(',
#   'PPB',
#   ')',
#   ',',
#   'e',
#   'ainda',
#   'pelo',
#   'Partido',
#   'Liberal',
#   '(',
#   'PL',
#   ')',
#   'e',
#   'o',
#   'Partido',
#   'Democrático',
#   'Trabalhista',
#   '(',
#   'PDT',
#   ')',
#   ',',
#   'além',
#   'de',
#   'agremiações',
#   'menores',
#   '.'],
#  ['Teve',
#   'como',
#   'principais',
#   'adversárias',
#   'a',
#   'ex-prefeita',
#   'de',
#   'Boa',
#   'Vista',
#   'Teresa',
#   'Jucá',
#   'e',
#   'a',
#   'senadora',
#   'Marluce',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'do',
#   'Movimento',
#   'Democrático',
#   'Brasileiro',
#   '(',
#   'PMDB',
#   ')',
#   ',',
#   'com',
#   'cujo',
#   'marido',
#   ',',
#   'Otomar',
#   'Pinto',
#   ',',
#   'prefeito',
#   'de',
#   'Boa',
#   'Vista',
#   ',',
#   'rompeu',
#   'depois',
#   'que',
#   'decidiu',
#   'concorrer',
#   'à',
#   'reeleição',
#   '.'],
#  ['Iniciou',
#   'seu',
#   'segundo',
#   'governo',
#   'em',
#   '1º',
#   'de',
#   'janeiro',
#   'de',
#   '1999',
#   ',',
#   'e',
#   'em',
#   '2000',
#   'deixou',
#   'o',
#   'PPB',
#   'e',
#   'filiou-se',
#   'ao',
#   'Partido',
#   'da',
#   'Frente',
#   'Liberal',
#   '(',
#   'PFL',
#   ')',
#   '.'],
#  ['Em',
#   'janeiro',
#   'de',
#   '2003',
#   'encerrou',
#   'o',
#   'governo',
#   ',',
#   'deixou',
#   'o',
#   'PFL',
#   'e',
#   'filiou-se',
#   'ao',
#   'Partido',
#   'Progressista',
#   '(',
#   'PP',
#   ')',
#   '.'],
#  ['De',
#   '2005',
#   'a',
#   '2006',
#   ',',
#   'foi',
#   'secretário',
#   'de',
#   'Governo',
#   'de',
#   'Roraima',
#   ',',
#   'na',
#   'gestão',
#   'de',
#   'Otomar',
#   'Pinto',
#   '(',
#   '2004-2007',
#   ')',
#   '.'],
#  ['Nesse',
#   'último',
#   'ano',
#   'concorreu',
#   'com',
#   'êxito',
#   'às',
#   'eleições',
#   'para',
#   'deputado',
#   'federal',
#   'na',
#   'legenda',
#   'do',
#   'PP',
#   '.'],
#  ['Assumindo',
#   'o',
#   'mandato',
#   'na',
#   'C',
#   "''",
#   'mara',
#   'em',
#   'fevereiro',
#   'de',
#   '2007',
#   ',',
#   'tornou-se',
#   'membro',
#   'titular',
#   'das',
#   'comissões',
#   'da',
#   'Amazônia',
#   ',',
#   'Integração',
#   'Nacional',
#   'e',
#   'de',
#   'Desenvolvimento',
#   'Regional',
#   ',',
#   'e',
#   'de',
#   'Minas',
#   'e',
#   'Energia',
#   '.'],
#  ['Casou-se',
#   'com',
#   'Sueli',
#   'Campos',
#   ',',
#   'deputada',
#   'federal',
#   'por',
#   'Roraima',
#   'de',
#   '2003',
#   'a',
#   '2007',
#   ',',
#   'e',
#   'vice-prefeita',
#   'de',
#   'Rio',
#   'Branco',
#   'a',
#   'partir',
#   'de',
#   '2009',
#   ',',
#   'com',
#   'quem',
#   'teve',
#   'quatro',
#   'filhos',
#   '.']]

# %%
frases_tokenizadas_nltk[8]
# Out:
# ['Em',
#  'julho',
#  'de',
#  '1995',
#  ',',
#  'em',
#  'artigo',
#  'publicado',
#  'no',
#  'jornal',
#  '«',
#  'O',
#  'Estado',
#  'de',
#  'S.',
#  'Paulo',
#  '»',
#  ',',
#  'manifestou-se',
#  'contrário',
#  'à',
#  'proposta',
#  'de',
#  'diminuição',
#  'do',
#  'número',
#  'de',
#  'parlamentares',
#  'apresentada',
#  'pelo',
#  'deputado',
#  'José',
#  'Genoíno',
#  ',',
#  'do',
#  'Partido',
#  'dos',
#  'Trabalhadores',
#  '(',
#  'PT',
#  ')',
#  ',',
#  'que',
#  'resultaria',
#  'em',
#  'perda',
#  'de',
#  'representação',
#  'para',
#  'os',
#  'estados',
#  'nortistas',
#  ',',
#  'apontando-a',
#  'como',
#  'demonstrativa',
#  'de',
#  'uma',
#  'visão',
#  'caolha',
#  '.']

# %% [markdown]
# # Vídeo 4: Removendo stopwords manualmente

# %%
! wget -O stopwords.txt https://raw.githubusercontent.com/stopwords-iso/stopwords-pt/master/stopwords-pt.txt
# Out:
# --2025-05-05 19:23:09--  https://raw.githubusercontent.com/stopwords-iso/stopwords-pt/master/stopwords-pt.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3609 (3.5K) [text/plain]
# Saving to: ‘stopwords.txt’
#
# stopwords.txt       100%[===================>]   3.52K  --.-KB/s    in 0s
#
# 2025-05-05 19:23:10 (41.2 MB/s) - ‘stopwords.txt’ saved [3609/3609]

# %%
with open("stopwords.txt") as f:
    stopwords = f.read()

# %%
print(stopwords)
# Out:
# a
# acerca
# adeus
# agora
# ainda
# alem
# algmas
# algo
# algumas
# alguns
# ali
# além
# ambas
# ambos
# ano
# anos
# antes
# ao
# aonde
# aos
# apenas
# apoio
# apontar
# apos
# após
# aquela
# aquelas
# aquele
# aqueles
# aqui
# aquilo
# as
# assim
# através
# atrás
# até
# aí
# baixo
# bastante
# bem
# boa
# boas
# bom
# bons
# breve
# cada
# caminho
# catorze
# cedo
# cento
# certamente
# certeza
# cima
# cinco
# coisa
# com
# como
# comprido
# conhecido
# conselho
# contra
# contudo
# corrente
# cuja
# cujas
# cujo
# cujos
# custa
# cá
# da
# daquela
# daquelas
# daquele
# daqueles
# dar
# das
# de
# debaixo
# dela
# delas
# dele
# deles
# demais
# dentro
# depois
# desde
# desligado
# dessa
# dessas
# desse
# desses
# desta
# destas
# deste
# destes
# deve
# devem
# deverá
# dez
# dezanove
# dezasseis
# dezassete
# dezoito
# dia
# diante
# direita
# dispoe
# dispoem
# diversa
# diversas
# diversos
# diz
# dizem
# dizer
# do
# dois
# dos
# doze
# duas
# durante
# dá
# dão
# dúvida
# e
# ela
# elas
# ele
# eles
# em
# embora
# enquanto
# entao
# entre
# então
# era
# eram
# essa
# essas
# esse
# esses
# esta
# estado
# estamos
# estar
# estará
# estas
# estava
# estavam
# este
# esteja
# estejam
# estejamos
# estes
# esteve
# estive
# estivemos
# estiver
# estivera
# estiveram
# estiverem
# estivermos
# estivesse
# estivessem
# estiveste
# estivestes
# estivéramos
# estivéssemos
# estou
# está
# estás
# estávamos
# estão
# eu
# exemplo
# falta
# fará
# favor
# faz
# fazeis
# fazem
# fazemos
# fazer
# fazes
# fazia
# faço
# fez
# fim
# final
# foi
# fomos
# for
# fora
# foram
# forem
# forma
# formos
# fosse
# fossem
# foste
# fostes
# fui
# fôramos
# fôssemos
# geral
# grande
# grandes
# grupo
# ha
# haja
# hajam
# hajamos
# havemos
# havia
# hei
# hoje
# hora
# horas
# houve
# houvemos
# houver
# houvera
# houveram
# houverei
# houverem
# houveremos
# houveria
# houveriam
# houvermos
# houverá
# houverão
# houveríamos
# houvesse
# houvessem
# houvéramos
# houvéssemos
# há
# hão
# iniciar
# inicio
# ir
# irá
# isso
# ista
# iste
# isto
# já
# lado
# lhe
# lhes
# ligado
# local
# logo
# longe
# lugar
# lá
# maior
# maioria
# maiorias
# mais
# mal
# mas
# me
# mediante
# meio
# menor
# menos
# meses
# mesma
# mesmas
# mesmo
# mesmos
# meu
# meus
# mil
# minha
# minhas
# momento
# muito
# muitos
# máximo
# mês
# na
# nada
# nao
# naquela
# naquelas
# naquele
# naqueles
# nas
# nem
# nenhuma
# nessa
# nessas
# nesse
# nesses
# nesta
# nestas
# neste
# nestes
# no
# noite
# nome
# nos
# nossa
# nossas
# nosso
# nossos
# nova
# novas
# nove
# novo
# novos
# num
# numa
# numas
# nunca
# nuns
# não
# nível
# nós
# número
# o
# obra
# obrigada
# obrigado
# oitava
# oitavo
# oito
# onde
# ontem
# onze
# os
# ou
# outra
# outras
# outro
# outros
# para
# parece
# parte
# partir
# paucas
# pegar
# pela
# pelas
# pelo
# pelos
# perante
# perto
# pessoas
# pode
# podem
# poder
# poderá
# podia
# pois
# ponto
# pontos
# por
# porque
# porquê
# portanto
# posição
# possivelmente
# posso
# possível
# pouca
# pouco
# poucos
# povo
# primeira
# primeiras
# primeiro
# primeiros
# promeiro
# propios
# proprio
# própria
# próprias
# próprio
# próprios
# próxima
# próximas
# próximo
# próximos
# puderam
# pôde
# põe
# põem
# quais
# qual
# qualquer
# quando
# quanto
# quarta
# quarto
# quatro
# que
# quem
# quer
# quereis
# querem
# queremas
# queres
# quero
# questão
# quieto
# quinta
# quinto
# quinze
# quáis
# quê
# relação
# sabe
# sabem
# saber
# se
# segunda
# segundo
# sei
# seis
# seja
# sejam
# sejamos
# sem
# sempre
# sendo
# ser
# serei
# seremos
# seria
# seriam
# será
# serão
# seríamos
# sete
# seu
# seus
# sexta
# sexto
# sim
# sistema
# sob
# sobre
# sois
# somente
# somos
# sou
# sua
# suas
# são
# sétima
# sétimo
# só
# tal
# talvez
# tambem
# também
# tanta
# tantas
# tanto
# tarde
# te
# tem
# temos
# tempo
# tendes
# tenha
# tenham
# tenhamos
# tenho
# tens
# tentar
# tentaram
# tente
# tentei
# ter
# terceira
# terceiro
# terei
# teremos
# teria
# teriam
# terá
# terão
# teríamos
# teu
# teus
# teve
# tinha
# tinham
# tipo
# tive
# tivemos
# tiver
# tivera
# tiveram
# tiverem
# tivermos
# tivesse
# tivessem
# tiveste
# tivestes
# tivéramos
# tivéssemos
# toda
# todas
# todo
# todos
# trabalhar
# trabalho
# treze
# três
# tu
# tua
# tuas
# tudo
# tão
# tém
# têm
# tínhamos
# um
# uma
# umas
# uns
# usa
# usar
# vai
# vais
# valor
# veja
# vem
# vens
# ver
# verdade
# verdadeiro
# vez
# vezes
# viagem
# vindo
# vinte
# você
# vocês
# vos
# vossa
# vossas
# vosso
# vossos
# vários
# vão
# vêm
# vós
# zero
# à
# às
# área
# é
# éramos
# és
# último

# %%
stopwords = stopwords.split("\n")

# %%
stopwords
# Out:
# ['a',
#  'acerca',
#  'adeus',
#  'agora',
#  'ainda',
#  'alem',
#  'algmas',
#  'algo',
#  'algumas',
#  'alguns',
#  'ali',
#  'além',
#  'ambas',
#  'ambos',
#  'ano',
#  'anos',
#  'antes',
#  'ao',
#  'aonde',
#  'aos',
#  'apenas',
#  'apoio',
#  'apontar',
#  'apos',
#  'após',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aqui',
#  'aquilo',
#  'as',
#  'assim',
#  'através',
#  'atrás',
#  'até',
#  'aí',
#  'baixo',
#  'bastante',
#  'bem',
#  'boa',
#  'boas',
#  'bom',
#  'bons',
#  'breve',
#  'cada',
#  'caminho',
#  'catorze',
#  'cedo',
#  'cento',
#  'certamente',
#  'certeza',
#  'cima',
#  'cinco',
#  'coisa',
#  'com',
#  'como',
#  'comprido',
#  'conhecido',
#  'conselho',
#  'contra',
#  'contudo',
#  'corrente',
#  'cuja',
#  'cujas',
#  'cujo',
#  'cujos',
#  'custa',
#  'cá',
#  'da',
#  'daquela',
#  'daquelas',
#  'daquele',
#  'daqueles',
#  'dar',
#  'das',
#  'de',
#  'debaixo',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'demais',
#  'dentro',
#  'depois',
#  'desde',
#  'desligado',
#  'dessa',
#  'dessas',
#  'desse',
#  'desses',
#  'desta',
#  'destas',
#  'deste',
#  'destes',
#  'deve',
#  'devem',
#  'deverá',
#  'dez',
#  'dezanove',
#  'dezasseis',
#  'dezassete',
#  'dezoito',
#  'dia',
#  'diante',
#  'direita',
#  'dispoe',
#  'dispoem',
#  'diversa',
#  'diversas',
#  'diversos',
#  'diz',
#  'dizem',
#  'dizer',
#  'do',
#  'dois',
#  'dos',
#  'doze',
#  'duas',
#  'durante',
#  'dá',
#  'dão',
#  'dúvida',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'embora',
#  'enquanto',
#  'entao',
#  'entre',
#  'então',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estado',
#  'estamos',
#  'estar',
#  'estará',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estiveste',
#  'estivestes',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estás',
#  'estávamos',
#  'estão',
#  'eu',
#  'exemplo',
#  'falta',
#  'fará',
#  'favor',
#  'faz',
#  'fazeis',
#  'fazem',
#  'fazemos',
#  'fazer',
#  'fazes',
#  'fazia',
#  'faço',
#  'fez',
#  'fim',
#  'final',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'forma',
#  'formos',
#  'fosse',
#  'fossem',
#  'foste',
#  'fostes',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'geral',
#  'grande',
#  'grandes',
#  'grupo',
#  'ha',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'havia',
#  'hei',
#  'hoje',
#  'hora',
#  'horas',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'iniciar',
#  'inicio',
#  'ir',
#  'irá',
#  'isso',
#  'ista',
#  'iste',
#  'isto',
#  'já',
#  'lado',
#  'lhe',
#  'lhes',
#  'ligado',
#  'local',
#  'logo',
#  'longe',
#  'lugar',
#  'lá',
#  'maior',
#  'maioria',
#  'maiorias',
#  'mais',
#  'mal',
#  'mas',
#  'me',
#  'mediante',
#  'meio',
#  'menor',
#  'menos',
#  'meses',
#  'mesma',
#  'mesmas',
#  'mesmo',
#  'mesmos',
#  'meu',
#  'meus',
#  'mil',
#  'minha',
#  'minhas',
#  'momento',
#  'muito',
#  'muitos',
#  'máximo',
#  'mês',
#  'na',
#  'nada',
#  'nao',
#  'naquela',
#  'naquelas',
#  'naquele',
#  'naqueles',
#  'nas',
#  'nem',
#  'nenhuma',
#  'nessa',
#  'nessas',
#  'nesse',
#  'nesses',
#  'nesta',
#  'nestas',
#  'neste',
#  'nestes',
#  'no',
#  'noite',
#  'nome',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'nova',
#  'novas',
#  'nove',
#  'novo',
#  'novos',
#  'num',
#  'numa',
#  'numas',
#  'nunca',
#  'nuns',
#  'não',
#  'nível',
#  'nós',
#  'número',
#  'o',
#  'obra',
#  'obrigada',
#  'obrigado',
#  'oitava',
#  'oitavo',
#  'oito',
#  'onde',
#  'ontem',
#  'onze',
#  'os',
#  'ou',
#  'outra',
#  'outras',
#  'outro',
#  'outros',
#  'para',
#  'parece',
#  'parte',
#  'partir',
#  'paucas',
#  'pegar',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'perante',
#  'perto',
#  'pessoas',
#  'pode',
#  'podem',
#  'poder',
#  'poderá',
#  'podia',
#  'pois',
#  'ponto',
#  'pontos',
#  'por',
#  'porque',
#  'porquê',
#  'portanto',
#  'posição',
#  'possivelmente',
#  'posso',
#  'possível',
#  'pouca',
#  'pouco',
#  'poucos',
#  'povo',
#  'primeira',
#  'primeiras',
#  'primeiro',
#  'primeiros',
#  'promeiro',
#  'propios',
#  'proprio',
#  'própria',
#  'próprias',
#  'próprio',
#  'próprios',
#  'próxima',
#  'próximas',
#  'próximo',
#  'próximos',
#  'puderam',
#  'pôde',
#  'põe',
#  'põem',
#  'quais',
#  'qual',
#  'qualquer',
#  'quando',
#  'quanto',
#  'quarta',
#  'quarto',
#  'quatro',
#  'que',
#  'quem',
#  'quer',
#  'quereis',
#  'querem',
#  'queremas',
#  'queres',
#  'quero',
#  'questão',
#  'quieto',
#  'quinta',
#  'quinto',
#  'quinze',
#  'quáis',
#  'quê',
#  'relação',
#  'sabe',
#  'sabem',
#  'saber',
#  'se',
#  'segunda',
#  'segundo',
#  'sei',
#  'seis',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'sempre',
#  'sendo',
#  'ser',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'sete',
#  'seu',
#  'seus',
#  'sexta',
#  'sexto',
#  'sim',
#  'sistema',
#  'sob',
#  'sobre',
#  'sois',
#  'somente',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'sétima',
#  'sétimo',
#  'só',
#  'tal',
#  'talvez',
#  'tambem',
#  'também',
#  'tanta',
#  'tantas',
#  'tanto',
#  'tarde',
#  'te',
#  'tem',
#  'temos',
#  'tempo',
#  'tendes',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'tens',
#  'tentar',
#  'tentaram',
#  'tente',
#  'tentei',
#  'ter',
#  'terceira',
#  'terceiro',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tipo',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tiveste',
#  'tivestes',
#  'tivéramos',
#  'tivéssemos',
#  'toda',
#  'todas',
#  'todo',
#  'todos',
#  'trabalhar',
#  'trabalho',
#  'treze',
#  'três',
#  'tu',
#  'tua',
#  'tuas',
#  'tudo',
#  'tão',
#  'tém',
#  'têm',
#  'tínhamos',
#  'um',
#  'uma',
#  'umas',
#  'uns',
#  'usa',
#  'usar',
#  'vai',
#  'vais',
#  'valor',
#  'veja',
#  'vem',
#  'vens',
#  'ver',
#  'verdade',
#  'verdadeiro',
#  'vez',
#  'vezes',
#  'viagem',
#  'vindo',
#  'vinte',
#  'você',
#  'vocês',
#  'vos',
#  'vossa',
#  'vossas',
#  'vosso',
#  'vossos',
#  'vários',
#  'vão',
#  'vêm',
#  'vós',
#  'zero',
#  'à',
#  'às',
#  'área',
#  'é',
#  'éramos',
#  'és',
#  'último']

# %%
frases_tokenizadas_nltk
# Out:
# [['«',
#   'Neudo',
#   'Ribeiro',
#   'Campos',
#   '»',
#   'nasceu',
#   'em',
#   'Boa',
#   'Vista',
#   'no',
#   'dia',
#   '1º',
#   'de',
#   'setembro',
#   'de',
#   '1946',
#   ',',
#   'filho',
#   'de',
#   'Antônio',
#   'Ribeiro',
#   'Campos',
#   'e',
#   'de',
#   'América',
#   'Sarmento',
#   'Ribeiro',
#   ',',
#   'família',
#   'tradicional',
#   'na',
#   'política',
#   'de',
#   'Roraima',
#   '.'],
#  ['Concluiu',
#   'os',
#   'cursos',
#   'primário',
#   'e',
#   'ginasial',
#   'em',
#   'sua',
#   'cidade',
#   'natal',
#   'nos',
#   'anos',
#   'de',
#   '1957',
#   'e',
#   '1962',
#   ',',
#   'respectivamente',
#   '.'],
#  ['Após',
#   'uma',
#   'breve',
#   'passagem',
#   'pelo',
#   'Colégio',
#   'Estadual',
#   'do',
#   'Amazonas',
#   ',',
#   'transferiu-se',
#   'em',
#   '1964',
#   'para',
#   'Belém',
#   ',',
#   'onde',
#   'terminou',
#   'o',
#   'segundo',
#   'grau',
#   'e',
#   'ingressou',
#   'na',
#   'Escola',
#   'de',
#   'Engenharia',
#   'da',
#   'Universidade',
#   'Federal',
#   'do',
#   'Pará',
#   '.'],
#  ['Formou-se',
#   'em',
#   '1970',
#   'e',
#   'especializou-se',
#   'na',
#   'área',
#   'de',
#   'tecnologia',
#   'de',
#   'concretos',
#   ',',
#   'tornando-se',
#   'empresário',
#   'da',
#   'construção',
#   'civil',
#   '.'],
#  ['Em',
#   '1990',
#   ',',
#   'na',
#   'primeira',
#   'eleição',
#   'direta',
#   'para',
#   'governador',
#   'de',
#   'Roraima',
#   'após',
#   'a',
#   'transformação',
#   'do',
#   'antigo',
#   'território',
#   'em',
#   'estado',
#   'pela',
#   'Constituição',
#   'de',
#   '1988',
#   ',',
#   'foi',
#   'lançado',
#   'candidato',
#   'pelo',
#   'Partido',
#   'da',
#   'Reconstrução',
#   'Nacional',
#   '(',
#   'PRN',
#   ')',
#   ',',
#   'que',
#   ',',
#   'em',
#   'dezembro',
#   'de',
#   '1989',
#   ',',
#   'elegera',
#   'Fernando',
#   'Collor',
#   'de',
#   'Melo',
#   'presidente',
#   'da',
#   'República',
#   '.'],
#  ['Realizada',
#   'a',
#   'eleição',
#   'em',
#   'outubro',
#   ',',
#   'foi',
#   'derrotado',
#   'por',
#   'Otomar',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'Trabalhista',
#   'Brasileiro',
#   '(',
#   'PTB',
#   ')',
#   '.'],
#  ['Transferindo-se',
#   'posteriormente',
#   'para',
#   'esse',
#   'partido',
#   ',',
#   'em',
#   'outubro',
#   'de',
#   '1994',
#   'concorreu',
#   'de',
#   'novo',
#   'ao',
#   'governo',
#   'estadual',
#   ',',
#   'dessa',
#   'vez',
#   'com',
#   'êxito',
#   '.'],
#  ['Ao',
#   'tomar',
#   'posse',
#   'em',
#   'janeiro',
#   'de',
#   '1995',
#   ',',
#   'garantiu',
#   'o',
#   'apoio',
#   'do',
#   'seu',
#   'governo',
#   'ao',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'em',
#   'troca',
#   'da',
#   'liberação',
#   'de',
#   'verbas',
#   'para',
#   'a',
#   'construção',
#   'da',
#   'usina',
#   'hidrelétrica',
#   'de',
#   'Cotingo',
#   'e',
#   'de',
#   'ajuda',
#   'financeira',
#   'para',
#   'dar',
#   'continuidade',
#   'às',
#   'obras',
#   'iniciadas',
#   'por',
#   'seu',
#   'antecessor',
#   '.'],
#  ['Em',
#   'julho',
#   'de',
#   '1995',
#   ',',
#   'em',
#   'artigo',
#   'publicado',
#   'no',
#   'jornal',
#   '«',
#   'O',
#   'Estado',
#   'de',
#   'S.',
#   'Paulo',
#   '»',
#   ',',
#   'manifestou-se',
#   'contrário',
#   'à',
#   'proposta',
#   'de',
#   'diminuição',
#   'do',
#   'número',
#   'de',
#   'parlamentares',
#   'apresentada',
#   'pelo',
#   'deputado',
#   'José',
#   'Genoíno',
#   ',',
#   'do',
#   'Partido',
#   'dos',
#   'Trabalhadores',
#   '(',
#   'PT',
#   ')',
#   ',',
#   'que',
#   'resultaria',
#   'em',
#   'perda',
#   'de',
#   'representação',
#   'para',
#   'os',
#   'estados',
#   'nortistas',
#   ',',
#   'apontando-a',
#   'como',
#   'demonstrativa',
#   'de',
#   'uma',
#   'visão',
#   'caolha',
#   '.'],
#  ['Contestou',
#   'a',
#   'afirmação',
#   'de',
#   'Genoíno',
#   'de',
#   'que',
#   'haveria',
#   'apenas',
#   'políticos',
#   'conservadores',
#   'e',
#   'clientelistas',
#   'nos',
#   'estados',
#   'do',
#   'Norte',
#   ',',
#   'citando',
#   'como',
#   'exemplo',
#   'de',
#   'bancadas',
#   'de',
#   'esquerda',
#   'expressivas',
#   'a',
#   'do',
#   'Acre',
#   ',',
#   'que',
#   'incluía',
#   'uma',
#   'senadora',
#   'filiada',
#   'ao',
#   'PT',
#   ',',
#   'e',
#   'a',
#   'do',
#   'Amapá',
#   ',',
#   'cujo',
#   'governador',
#   'era',
#   'filiado',
#   'ao',
#   'Partido',
#   'Socialista',
#   'Brasileiro',
#   '(',
#   'PSB',
#   ')',
#   '.'],
#  ['Em',
#   'setembro',
#   'de',
#   '1995',
#   ',',
#   'admitiu',
#   'que',
#   'Roraima',
#   ',',
#   'sete',
#   'anos',
#   'depois',
#   'de',
#   'se',
#   'tornar',
#   'estado',
#   ',',
#   'ainda',
#   'vivia',
#   'à',
#   'custa',
#   'da',
#   'União',
#   ',',
#   'ao',
#   'afirmar',
#   ':',
#   'Sem',
#   'as',
#   'verbas',
#   'federais',
#   ',',
#   'o',
#   'estado',
#   'quebra',
#   '.'],
#  ['No',
#   'mesmo',
#   'mês',
#   ',',
#   'anunciou',
#   'o',
#   'investimento',
#   'de',
#   '15',
#   'milhões',
#   'de',
#   'reais',
#   'para',
#   'asfaltar',
#   'a',
#   'BR-174',
#   'até',
#   'a',
#   'fronteira',
#   'com',
#   'o',
#   'Amazonas',
#   ',',
#   'obra',
#   'fundamental',
#   ',',
#   'do',
#   'seu',
#   'ponto',
#   'de',
#   'vista',
#   ',',
#   'para',
#   'transformar',
#   'Roraima',
#   'num',
#   'grande',
#   'corredor',
#   'de',
#   'exportação',
#   'rumo',
#   'aos',
#   'mercados',
#   'do',
#   'Caribe',
#   'e',
#   'do',
#   'Nafta',
#   '.'],
#  ['No',
#   'final',
#   'de',
#   'janeiro',
#   'de',
#   '1998',
#   ',',
#   'decretou',
#   'estado',
#   'de',
#   'calamidade',
#   'pública',
#   'em',
#   'Roraima',
#   'devido',
#   'à',
#   'seca',
#   'prolongada',
#   'e',
#   'à',
#   'falta',
#   'de',
#   'água',
#   'potável',
#   ',',
#   'situação',
#   'que',
#   'levaria',
#   'o',
#   'estado',
#   'a',
#   'enfrentar',
#   'um',
#   'dos',
#   'piores',
#   'incêndios',
#   'de',
#   'sua',
#   'história',
#   'durante',
#   'três',
#   'meses',
#   ',',
#   'causando',
#   'a',
#   'devastação',
#   'de',
#   'quase',
#   'dez',
#   'mil',
#   'metros',
#   'quadrados',
#   'de',
#   'floresta',
#   '.'],
#  ['Como',
#   'o',
#   'auxílio',
#   'do',
#   'governo',
#   'federal',
#   'só',
#   'chegou',
#   'em',
#   'meados',
#   'de',
#   'março',
#   ',',
#   'criticou',
#   'o',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'por',
#   'não',
#   'tê-lo',
#   'ajudado',
#   'desde',
#   'o',
#   'início',
#   'a',
#   'combater',
#   'a',
#   'catástrofe',
#   '.'],
#  ['No',
#   'mês',
#   'de',
#   'junho',
#   ',',
#   'veio',
#   'à',
#   'tona',
#   'um',
#   'amplo',
#   'esquema',
#   'de',
#   'corrupção',
#   'montado',
#   'no',
#   'interior',
#   'da',
#   'Companhia',
#   'de',
#   'Desenvolvimento',
#   'de',
#   'Roraima',
#   '(',
#   'Condesaima',
#   ')',
#   'desde',
#   'o',
#   'início',
#   'de',
#   'sua',
#   'administração',
#   '.'],
#  ['As',
#   'denúncias',
#   ',',
#   'veiculadas',
#   'por',
#   'Ronald',
#   'Jorge',
#   'P.',
#   'Santos',
#   'Filho',
#   '-',
#   'um',
#   'dos',
#   'envolvidos',
#   'na',
#   'trama',
#   'e',
#   'que',
#   'assim',
#   'agiu',
#   'por',
#   'sentir-se',
#   'traído',
#   '-',
#   ',',
#   'incriminavam',
#   'diretamente',
#   'dois',
#   'concunhados',
#   'do',
#   'governador',
#   ',',
#   'que',
#   'teriam',
#   'criado',
#   'uma',
#   'empresa-fantasma',
#   'supostamente',
#   'destinada',
#   'a',
#   'fornecer',
#   'produtos',
#   'à',
#   'Condesaima',
#   'e',
#   'outros',
#   'órgãos',
#   'públicos',
#   '.'],
#  ['O',
#   'testa-de-ferro',
#   'seria',
#   'Ronald',
#   'Jorge',
#   ',',
#   'que',
#   'apresentava',
#   'notas',
#   'fiscais',
#   'frias',
#   'como',
#   'se',
#   'estivesse',
#   'realmente',
#   'fornecendo',
#   'os',
#   'produtos',
#   '.'],
#  ['Ao',
#   'receber',
#   'o',
#   'dinheiro',
#   ',',
#   'devolvia-o',
#   'para',
#   'os',
#   'contraparentes',
#   'do',
#   'governador',
#   '.'],
#  ['Em',
#   'setembro',
#   ',',
#   'o',
#   'jornal',
#   '«',
#   'O',
#   'Globo',
#   '»',
#   'divulgou',
#   'matéria',
#   'revelando',
#   'a',
#   'existência',
#   'de',
#   'um',
#   'conjunto',
#   'de',
#   'fitas',
#   'contendo',
#   'gravações',
#   'de',
#   'conversas',
#   'de',
#   'Neudo',
#   'Campos',
#   ',',
#   'que',
#   'serviria',
#   'de',
#   'base',
#   'para',
#   'a',
#   'denúncia',
#   'de',
#   'desvio',
#   'de',
#   'recursos',
#   'de',
#   'órgãos',
#   'estatais',
#   'para',
#   'sua',
#   'campanha',
#   'à',
#   'reeleição',
#   '.'],
#  ['O',
#   'teor',
#   'das',
#   'conversas',
#   'comprometia',
#   'o',
#   'secretário',
#   'de',
#   'Fazenda',
#   ',',
#   'Roberto',
#   'Leonel',
#   ';',
#   'a',
#   'chefe',
#   'do',
#   'Gabinete',
#   'Civil',
#   ',',
#   'Cilene',
#   'Salomão',
#   ',',
#   'acusada',
#   'de',
#   'articular',
#   'operações',
#   'de',
#   'triangulação',
#   'e',
#   'distribuição',
#   'de',
#   'recursos',
#   'para',
#   'a',
#   'campanha',
#   ';',
#   'e',
#   'parentes',
#   'do',
#   'governador',
#   'que',
#   'ocupavam',
#   'cargos',
#   'de',
#   'direção',
#   'na',
#   'Condesaima',
#   '.'],
#  ['De',
#   'acordo',
#   'com',
#   'as',
#   'gravações',
#   ',',
#   'o',
#   'dinheiro',
#   'era',
#   'desviado',
#   'da',
#   'Secretaria',
#   'de',
#   'Fazenda',
#   'e',
#   'repassado',
#   'para',
#   'a',
#   'Condesaima',
#   ',',
#   'que',
#   'por',
#   'sua',
#   'vez',
#   'tinha',
#   'a',
#   'incumbência',
#   'de',
#   'entregar',
#   'os',
#   'pacotes',
#   'com',
#   'as',
#   'cédulas',
#   'para',
#   'assessores',
#   'do',
#   'governador',
#   '.'],
#  ['Durante',
#   'as',
#   'investigações',
#   ',',
#   'o',
#   'juiz',
#   'de',
#   'primeira',
#   'inst',
#   "''",
#   'ncia',
#   'Hélder',
#   'Girão',
#   'Barreto',
#   'julgou',
#   'procedente',
#   'uma',
#   'ação',
#   'popular',
#   'requerendo',
#   'a',
#   'demissão',
#   'de',
#   '17',
#   'parentes',
#   'do',
#   'governador',
#   ',',
#   'sob',
#   'a',
#   'acusação',
#   'de',
#   'desviarem',
#   'recursos',
#   'públicos',
#   'para',
#   'a',
#   'campanha',
#   'e',
#   'de',
#   'criarem',
#   'empresas-fantasmas',
#   'para',
#   'fornecer',
#   'suprimentos',
#   'à',
#   'Condesaima',
#   ',',
#   'e',
#   'determinou',
#   'ainda',
#   'a',
#   'demissão',
#   'de',
#   'todos',
#   'os',
#   'parentes',
#   'dos',
#   'desembargadores',
#   'que',
#   'lotavam',
#   'o',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   '.'],
#  ['Além',
#   'disso',
#   ',',
#   'deu',
#   'parecer',
#   'favorável',
#   'ao',
#   'pedido',
#   'de',
#   'quebra',
#   'de',
#   'sigilo',
#   'bancário',
#   'de',
#   'oito',
#   'auxiliares',
#   'do',
#   'governador',
#   'que',
#   'estariam',
#   'na',
#   'ponta',
#   'do',
#   'esquema',
#   'de',
#   'corrupção',
#   'denunciado',
#   'por',
#   'Ronald',
#   'Jorge',
#   '.'],
#  ['Como',
#   'resultado',
#   'de',
#   'sua',
#   'decisão',
#   ',',
#   'além',
#   'de',
#   'ser',
#   'afastado',
#   'das',
#   'funções',
#   'que',
#   'exercia',
#   'e',
#   'de',
#   'ser',
#   'alvo',
#   'de',
#   'um',
#   'processo',
#   'administrativo',
#   'por',
#   'supostas',
#   'faltas',
#   'disciplinares',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'teve',
#   'todas',
#   'as',
#   'suas',
#   'decisões',
#   'cassadas',
#   'pelo',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'do',
#   'estado',
#   '.'],
#  ['Os',
#   'parentes',
#   'acusados',
#   'do',
#   'governador',
#   'só',
#   'foram',
#   'demitidos',
#   'devido',
#   'às',
#   'proporções',
#   'atingidas',
#   'pelo',
#   'esc',
#   "''",
#   'ndalo',
#   '.'],
#  ['Por',
#   'conta',
#   'disso',
#   ',',
#   'o',
#   'Supremo',
#   'Tribunal',
#   'Federal',
#   '(',
#   'STF',
#   ')',
#   'acabou',
#   'por',
#   'intervir',
#   'no',
#   'Tribunal',
#   'de',
#   'Justiça',
#   'de',
#   'Roraima',
#   ',',
#   'suspeito',
#   'de',
#   'tentar',
#   'obstruir',
#   'a',
#   'investigação',
#   'das',
#   'denúncias',
#   'de',
#   'corrupção',
#   'e',
#   'nepotismo',
#   'contra',
#   'o',
#   'governador',
#   ',',
#   'e',
#   'por',
#   'reintegrar',
#   ',',
#   'por',
#   'unanimidade',
#   ',',
#   'o',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   ',',
#   'ao',
#   'decidir',
#   'que',
#   'cinco',
#   'dos',
#   'seis',
#   'desembargadores',
#   'daquela',
#   'corte',
#   'estavam',
#   'impedidos',
#   'de',
#   'julgar',
#   'o',
#   'mandado',
#   'de',
#   'segurança',
#   'por',
#   'ele',
#   'impetrado',
#   ',',
#   'já',
#   'que',
#   'haviam',
#   'tido',
#   'parentes',
#   'demitidos',
#   'do',
#   'tribunal',
#   'por',
#   'decisão',
#   'do',
#   'juiz',
#   '.'],
#  ['A',
#   'despeito',
#   'de',
#   'tais',
#   'denúncias',
#   ',',
#   'Neudo',
#   'Campos',
#   'disputou',
#   'com',
#   'êxito',
#   'a',
#   'reeleição',
#   'em',
#   'outubro',
#   'de',
#   '1998',
#   ',',
#   'à',
#   'frente',
#   'de',
#   'coligação',
#   'integrada',
#   'por',
#   'seu',
#   'partido',
#   ',',
#   'o',
#   'Partido',
#   'Progressista',
#   'Brasileiro',
#   '(',
#   'PPB',
#   ')',
#   ',',
#   'e',
#   'ainda',
#   'pelo',
#   'Partido',
#   'Liberal',
#   '(',
#   'PL',
#   ')',
#   'e',
#   'o',
#   'Partido',
#   'Democrático',
#   'Trabalhista',
#   '(',
#   'PDT',
#   ')',
#   ',',
#   'além',
#   'de',
#   'agremiações',
#   'menores',
#   '.'],
#  ['Teve',
#   'como',
#   'principais',
#   'adversárias',
#   'a',
#   'ex-prefeita',
#   'de',
#   'Boa',
#   'Vista',
#   'Teresa',
#   'Jucá',
#   'e',
#   'a',
#   'senadora',
#   'Marluce',
#   'Pinto',
#   ',',
#   'do',
#   'Partido',
#   'do',
#   'Movimento',
#   'Democrático',
#   'Brasileiro',
#   '(',
#   'PMDB',
#   ')',
#   ',',
#   'com',
#   'cujo',
#   'marido',
#   ',',
#   'Otomar',
#   'Pinto',
#   ',',
#   'prefeito',
#   'de',
#   'Boa',
#   'Vista',
#   ',',
#   'rompeu',
#   'depois',
#   'que',
#   'decidiu',
#   'concorrer',
#   'à',
#   'reeleição',
#   '.'],
#  ['Iniciou',
#   'seu',
#   'segundo',
#   'governo',
#   'em',
#   '1º',
#   'de',
#   'janeiro',
#   'de',
#   '1999',
#   ',',
#   'e',
#   'em',
#   '2000',
#   'deixou',
#   'o',
#   'PPB',
#   'e',
#   'filiou-se',
#   'ao',
#   'Partido',
#   'da',
#   'Frente',
#   'Liberal',
#   '(',
#   'PFL',
#   ')',
#   '.'],
#  ['Em',
#   'janeiro',
#   'de',
#   '2003',
#   'encerrou',
#   'o',
#   'governo',
#   ',',
#   'deixou',
#   'o',
#   'PFL',
#   'e',
#   'filiou-se',
#   'ao',
#   'Partido',
#   'Progressista',
#   '(',
#   'PP',
#   ')',
#   '.'],
#  ['De',
#   '2005',
#   'a',
#   '2006',
#   ',',
#   'foi',
#   'secretário',
#   'de',
#   'Governo',
#   'de',
#   'Roraima',
#   ',',
#   'na',
#   'gestão',
#   'de',
#   'Otomar',
#   'Pinto',
#   '(',
#   '2004-2007',
#   ')',
#   '.'],
#  ['Nesse',
#   'último',
#   'ano',
#   'concorreu',
#   'com',
#   'êxito',
#   'às',
#   'eleições',
#   'para',
#   'deputado',
#   'federal',
#   'na',
#   'legenda',
#   'do',
#   'PP',
#   '.'],
#  ['Assumindo',
#   'o',
#   'mandato',
#   'na',
#   'C',
#   "''",
#   'mara',
#   'em',
#   'fevereiro',
#   'de',
#   '2007',
#   ',',
#   'tornou-se',
#   'membro',
#   'titular',
#   'das',
#   'comissões',
#   'da',
#   'Amazônia',
#   ',',
#   'Integração',
#   'Nacional',
#   'e',
#   'de',
#   'Desenvolvimento',
#   'Regional',
#   ',',
#   'e',
#   'de',
#   'Minas',
#   'e',
#   'Energia',
#   '.'],
#  ['Casou-se',
#   'com',
#   'Sueli',
#   'Campos',
#   ',',
#   'deputada',
#   'federal',
#   'por',
#   'Roraima',
#   'de',
#   '2003',
#   'a',
#   '2007',
#   ',',
#   'e',
#   'vice-prefeita',
#   'de',
#   'Rio',
#   'Branco',
#   'a',
#   'partir',
#   'de',
#   '2009',
#   ',',
#   'com',
#   'quem',
#   'teve',
#   'quatro',
#   'filhos',
#   '.']]

# %%
frases_sem_stopwords = []

for frase in frases_tokenizadas_nltk:
    frase_sem_stopwords = []
    for token in frase:
        if not token.lower() in stopwords:
            frase_sem_stopwords.append(token)
    frases_sem_stopwords.append(frase_sem_stopwords)

# %%
frases_sem_stopwords
# Out:
# [['«',
#   'Neudo',
#   'Ribeiro',
#   'Campos',
#   '»',
#   'nasceu',
#   'Vista',
#   '1º',
#   'setembro',
#   '1946',
#   ',',
#   'filho',
#   'Antônio',
#   'Ribeiro',
#   'Campos',
#   'América',
#   'Sarmento',
#   'Ribeiro',
#   ',',
#   'família',
#   'tradicional',
#   'política',
#   'Roraima',
#   '.'],
#  ['Concluiu',
#   'cursos',
#   'primário',
#   'ginasial',
#   'cidade',
#   'natal',
#   '1957',
#   '1962',
#   ',',
#   'respectivamente',
#   '.'],
#  ['passagem',
#   'Colégio',
#   'Estadual',
#   'Amazonas',
#   ',',
#   'transferiu-se',
#   '1964',
#   'Belém',
#   ',',
#   'terminou',
#   'grau',
#   'ingressou',
#   'Escola',
#   'Engenharia',
#   'Universidade',
#   'Federal',
#   'Pará',
#   '.'],
#  ['Formou-se',
#   '1970',
#   'especializou-se',
#   'tecnologia',
#   'concretos',
#   ',',
#   'tornando-se',
#   'empresário',
#   'construção',
#   'civil',
#   '.'],
#  ['1990',
#   ',',
#   'eleição',
#   'direta',
#   'governador',
#   'Roraima',
#   'transformação',
#   'antigo',
#   'território',
#   'Constituição',
#   '1988',
#   ',',
#   'lançado',
#   'candidato',
#   'Partido',
#   'Reconstrução',
#   'Nacional',
#   '(',
#   'PRN',
#   ')',
#   ',',
#   ',',
#   'dezembro',
#   '1989',
#   ',',
#   'elegera',
#   'Fernando',
#   'Collor',
#   'Melo',
#   'presidente',
#   'República',
#   '.'],
#  ['Realizada',
#   'eleição',
#   'outubro',
#   ',',
#   'derrotado',
#   'Otomar',
#   'Pinto',
#   ',',
#   'Partido',
#   'Trabalhista',
#   'Brasileiro',
#   '(',
#   'PTB',
#   ')',
#   '.'],
#  ['Transferindo-se',
#   'posteriormente',
#   'partido',
#   ',',
#   'outubro',
#   '1994',
#   'concorreu',
#   'governo',
#   'estadual',
#   ',',
#   'êxito',
#   '.'],
#  ['tomar',
#   'posse',
#   'janeiro',
#   '1995',
#   ',',
#   'garantiu',
#   'governo',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'troca',
#   'liberação',
#   'verbas',
#   'construção',
#   'usina',
#   'hidrelétrica',
#   'Cotingo',
#   'ajuda',
#   'financeira',
#   'continuidade',
#   'obras',
#   'iniciadas',
#   'antecessor',
#   '.'],
#  ['julho',
#   '1995',
#   ',',
#   'artigo',
#   'publicado',
#   'jornal',
#   '«',
#   'S.',
#   'Paulo',
#   '»',
#   ',',
#   'manifestou-se',
#   'contrário',
#   'proposta',
#   'diminuição',
#   'parlamentares',
#   'apresentada',
#   'deputado',
#   'José',
#   'Genoíno',
#   ',',
#   'Partido',
#   'Trabalhadores',
#   '(',
#   'PT',
#   ')',
#   ',',
#   'resultaria',
#   'perda',
#   'representação',
#   'estados',
#   'nortistas',
#   ',',
#   'apontando-a',
#   'demonstrativa',
#   'visão',
#   'caolha',
#   '.'],
#  ['Contestou',
#   'afirmação',
#   'Genoíno',
#   'haveria',
#   'políticos',
#   'conservadores',
#   'clientelistas',
#   'estados',
#   'Norte',
#   ',',
#   'citando',
#   'bancadas',
#   'esquerda',
#   'expressivas',
#   'Acre',
#   ',',
#   'incluía',
#   'senadora',
#   'filiada',
#   'PT',
#   ',',
#   'Amapá',
#   ',',
#   'governador',
#   'filiado',
#   'Partido',
#   'Socialista',
#   'Brasileiro',
#   '(',
#   'PSB',
#   ')',
#   '.'],
#  ['setembro',
#   '1995',
#   ',',
#   'admitiu',
#   'Roraima',
#   ',',
#   'tornar',
#   ',',
#   'vivia',
#   'União',
#   ',',
#   'afirmar',
#   ':',
#   'verbas',
#   'federais',
#   ',',
#   'quebra',
#   '.'],
#  [',',
#   'anunciou',
#   'investimento',
#   '15',
#   'milhões',
#   'reais',
#   'asfaltar',
#   'BR-174',
#   'fronteira',
#   'Amazonas',
#   ',',
#   'fundamental',
#   ',',
#   'vista',
#   ',',
#   'transformar',
#   'Roraima',
#   'corredor',
#   'exportação',
#   'rumo',
#   'mercados',
#   'Caribe',
#   'Nafta',
#   '.'],
#  ['janeiro',
#   '1998',
#   ',',
#   'decretou',
#   'calamidade',
#   'pública',
#   'Roraima',
#   'devido',
#   'seca',
#   'prolongada',
#   'água',
#   'potável',
#   ',',
#   'situação',
#   'levaria',
#   'enfrentar',
#   'piores',
#   'incêndios',
#   'história',
#   ',',
#   'causando',
#   'devastação',
#   'quase',
#   'metros',
#   'quadrados',
#   'floresta',
#   '.'],
#  ['auxílio',
#   'governo',
#   'federal',
#   'chegou',
#   'meados',
#   'março',
#   ',',
#   'criticou',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'tê-lo',
#   'ajudado',
#   'início',
#   'combater',
#   'catástrofe',
#   '.'],
#  ['junho',
#   ',',
#   'veio',
#   'tona',
#   'amplo',
#   'esquema',
#   'corrupção',
#   'montado',
#   'interior',
#   'Companhia',
#   'Desenvolvimento',
#   'Roraima',
#   '(',
#   'Condesaima',
#   ')',
#   'início',
#   'administração',
#   '.'],
#  ['denúncias',
#   ',',
#   'veiculadas',
#   'Ronald',
#   'Jorge',
#   'P.',
#   'Santos',
#   'Filho',
#   '-',
#   'envolvidos',
#   'trama',
#   'agiu',
#   'sentir-se',
#   'traído',
#   '-',
#   ',',
#   'incriminavam',
#   'diretamente',
#   'concunhados',
#   'governador',
#   ',',
#   'criado',
#   'empresa-fantasma',
#   'supostamente',
#   'destinada',
#   'fornecer',
#   'produtos',
#   'Condesaima',
#   'órgãos',
#   'públicos',
#   '.'],
#  ['testa-de-ferro',
#   'Ronald',
#   'Jorge',
#   ',',
#   'apresentava',
#   'notas',
#   'fiscais',
#   'frias',
#   'realmente',
#   'fornecendo',
#   'produtos',
#   '.'],
#  ['receber',
#   'dinheiro',
#   ',',
#   'devolvia-o',
#   'contraparentes',
#   'governador',
#   '.'],
#  ['setembro',
#   ',',
#   'jornal',
#   '«',
#   'Globo',
#   '»',
#   'divulgou',
#   'matéria',
#   'revelando',
#   'existência',
#   'conjunto',
#   'fitas',
#   'contendo',
#   'gravações',
#   'conversas',
#   'Neudo',
#   'Campos',
#   ',',
#   'serviria',
#   'base',
#   'denúncia',
#   'desvio',
#   'recursos',
#   'órgãos',
#   'estatais',
#   'campanha',
#   'reeleição',
#   '.'],
#  ['teor',
#   'conversas',
#   'comprometia',
#   'secretário',
#   'Fazenda',
#   ',',
#   'Roberto',
#   'Leonel',
#   ';',
#   'chefe',
#   'Gabinete',
#   'Civil',
#   ',',
#   'Cilene',
#   'Salomão',
#   ',',
#   'acusada',
#   'articular',
#   'operações',
#   'triangulação',
#   'distribuição',
#   'recursos',
#   'campanha',
#   ';',
#   'parentes',
#   'governador',
#   'ocupavam',
#   'cargos',
#   'direção',
#   'Condesaima',
#   '.'],
#  ['acordo',
#   'gravações',
#   ',',
#   'dinheiro',
#   'desviado',
#   'Secretaria',
#   'Fazenda',
#   'repassado',
#   'Condesaima',
#   ',',
#   'incumbência',
#   'entregar',
#   'pacotes',
#   'cédulas',
#   'assessores',
#   'governador',
#   '.'],
#  ['investigações',
#   ',',
#   'juiz',
#   'inst',
#   "''",
#   'ncia',
#   'Hélder',
#   'Girão',
#   'Barreto',
#   'julgou',
#   'procedente',
#   'ação',
#   'popular',
#   'requerendo',
#   'demissão',
#   '17',
#   'parentes',
#   'governador',
#   ',',
#   'acusação',
#   'desviarem',
#   'recursos',
#   'públicos',
#   'campanha',
#   'criarem',
#   'empresas-fantasmas',
#   'fornecer',
#   'suprimentos',
#   'Condesaima',
#   ',',
#   'determinou',
#   'demissão',
#   'parentes',
#   'desembargadores',
#   'lotavam',
#   'Tribunal',
#   'Justiça',
#   'Roraima',
#   '.'],
#  ['disso',
#   ',',
#   'deu',
#   'parecer',
#   'favorável',
#   'pedido',
#   'quebra',
#   'sigilo',
#   'bancário',
#   'auxiliares',
#   'governador',
#   'estariam',
#   'ponta',
#   'esquema',
#   'corrupção',
#   'denunciado',
#   'Ronald',
#   'Jorge',
#   '.'],
#  ['resultado',
#   'decisão',
#   ',',
#   'afastado',
#   'funções',
#   'exercia',
#   'alvo',
#   'processo',
#   'administrativo',
#   'supostas',
#   'faltas',
#   'disciplinares',
#   ',',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'decisões',
#   'cassadas',
#   'Tribunal',
#   'Justiça',
#   '.'],
#  ['parentes',
#   'acusados',
#   'governador',
#   'demitidos',
#   'devido',
#   'proporções',
#   'atingidas',
#   'esc',
#   "''",
#   'ndalo',
#   '.'],
#  ['conta',
#   'disso',
#   ',',
#   'Supremo',
#   'Tribunal',
#   'Federal',
#   '(',
#   'STF',
#   ')',
#   'acabou',
#   'intervir',
#   'Tribunal',
#   'Justiça',
#   'Roraima',
#   ',',
#   'suspeito',
#   'obstruir',
#   'investigação',
#   'denúncias',
#   'corrupção',
#   'nepotismo',
#   'governador',
#   ',',
#   'reintegrar',
#   ',',
#   'unanimidade',
#   ',',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   ',',
#   'decidir',
#   'desembargadores',
#   'corte',
#   'impedidos',
#   'julgar',
#   'mandado',
#   'segurança',
#   'impetrado',
#   ',',
#   'haviam',
#   'tido',
#   'parentes',
#   'demitidos',
#   'tribunal',
#   'decisão',
#   'juiz',
#   '.'],
#  ['despeito',
#   'tais',
#   'denúncias',
#   ',',
#   'Neudo',
#   'Campos',
#   'disputou',
#   'êxito',
#   'reeleição',
#   'outubro',
#   '1998',
#   ',',
#   'frente',
#   'coligação',
#   'integrada',
#   'partido',
#   ',',
#   'Partido',
#   'Progressista',
#   'Brasileiro',
#   '(',
#   'PPB',
#   ')',
#   ',',
#   'Partido',
#   'Liberal',
#   '(',
#   'PL',
#   ')',
#   'Partido',
#   'Democrático',
#   'Trabalhista',
#   '(',
#   'PDT',
#   ')',
#   ',',
#   'agremiações',
#   'menores',
#   '.'],
#  ['principais',
#   'adversárias',
#   'ex-prefeita',
#   'Vista',
#   'Teresa',
#   'Jucá',
#   'senadora',
#   'Marluce',
#   'Pinto',
#   ',',
#   'Partido',
#   'Movimento',
#   'Democrático',
#   'Brasileiro',
#   '(',
#   'PMDB',
#   ')',
#   ',',
#   'marido',
#   ',',
#   'Otomar',
#   'Pinto',
#   ',',
#   'prefeito',
#   'Vista',
#   ',',
#   'rompeu',
#   'decidiu',
#   'concorrer',
#   'reeleição',
#   '.'],
#  ['Iniciou',
#   'governo',
#   '1º',
#   'janeiro',
#   '1999',
#   ',',
#   '2000',
#   'deixou',
#   'PPB',
#   'filiou-se',
#   'Partido',
#   'Frente',
#   'Liberal',
#   '(',
#   'PFL',
#   ')',
#   '.'],
#  ['janeiro',
#   '2003',
#   'encerrou',
#   'governo',
#   ',',
#   'deixou',
#   'PFL',
#   'filiou-se',
#   'Partido',
#   'Progressista',
#   '(',
#   'PP',
#   ')',
#   '.'],
#  ['2005',
#   '2006',
#   ',',
#   'secretário',
#   'Governo',
#   'Roraima',
#   ',',
#   'gestão',
#   'Otomar',
#   'Pinto',
#   '(',
#   '2004-2007',
#   ')',
#   '.'],
#  ['concorreu',
#   'êxito',
#   'eleições',
#   'deputado',
#   'federal',
#   'legenda',
#   'PP',
#   '.'],
#  ['Assumindo',
#   'mandato',
#   'C',
#   "''",
#   'mara',
#   'fevereiro',
#   '2007',
#   ',',
#   'tornou-se',
#   'membro',
#   'titular',
#   'comissões',
#   'Amazônia',
#   ',',
#   'Integração',
#   'Nacional',
#   'Desenvolvimento',
#   'Regional',
#   ',',
#   'Minas',
#   'Energia',
#   '.'],
#  ['Casou-se',
#   'Sueli',
#   'Campos',
#   ',',
#   'deputada',
#   'federal',
#   'Roraima',
#   '2003',
#   '2007',
#   ',',
#   'vice-prefeita',
#   'Rio',
#   'Branco',
#   '2009',
#   ',',
#   'filhos',
#   '.']]

# %% [markdown]
# # Removendo stopwords usando NLTK

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.corpus.stopwords.words('portuguese')
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
frases_sem_stopwords_nltk = []

for frase in frases_tokenizadas_nltk:
    frase_sem_stopwords = []
    for token in frase:
        if not token.lower() in nltk.corpus.stopwords.words('portuguese') and not token in string.punctuation:
            frase_sem_stopwords.append(token)
    frases_sem_stopwords_nltk.append(frase_sem_stopwords)

# %%
frases_sem_stopwords_nltk
# Out:
# [['«',
#   'Neudo',
#   'Ribeiro',
#   'Campos',
#   '»',
#   'nasceu',
#   'Boa',
#   'Vista',
#   'dia',
#   '1º',
#   'setembro',
#   '1946',
#   'filho',
#   'Antônio',
#   'Ribeiro',
#   'Campos',
#   'América',
#   'Sarmento',
#   'Ribeiro',
#   'família',
#   'tradicional',
#   'política',
#   'Roraima'],
#  ['Concluiu',
#   'cursos',
#   'primário',
#   'ginasial',
#   'cidade',
#   'natal',
#   'anos',
#   '1957',
#   '1962',
#   'respectivamente'],
#  ['Após',
#   'breve',
#   'passagem',
#   'Colégio',
#   'Estadual',
#   'Amazonas',
#   'transferiu-se',
#   '1964',
#   'Belém',
#   'onde',
#   'terminou',
#   'segundo',
#   'grau',
#   'ingressou',
#   'Escola',
#   'Engenharia',
#   'Universidade',
#   'Federal',
#   'Pará'],
#  ['Formou-se',
#   '1970',
#   'especializou-se',
#   'área',
#   'tecnologia',
#   'concretos',
#   'tornando-se',
#   'empresário',
#   'construção',
#   'civil'],
#  ['1990',
#   'primeira',
#   'eleição',
#   'direta',
#   'governador',
#   'Roraima',
#   'após',
#   'transformação',
#   'antigo',
#   'território',
#   'estado',
#   'Constituição',
#   '1988',
#   'lançado',
#   'candidato',
#   'Partido',
#   'Reconstrução',
#   'Nacional',
#   'PRN',
#   'dezembro',
#   '1989',
#   'elegera',
#   'Fernando',
#   'Collor',
#   'Melo',
#   'presidente',
#   'República'],
#  ['Realizada',
#   'eleição',
#   'outubro',
#   'derrotado',
#   'Otomar',
#   'Pinto',
#   'Partido',
#   'Trabalhista',
#   'Brasileiro',
#   'PTB'],
#  ['Transferindo-se',
#   'posteriormente',
#   'partido',
#   'outubro',
#   '1994',
#   'concorreu',
#   'novo',
#   'governo',
#   'estadual',
#   'dessa',
#   'vez',
#   'êxito'],
#  ['tomar',
#   'posse',
#   'janeiro',
#   '1995',
#   'garantiu',
#   'apoio',
#   'governo',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'troca',
#   'liberação',
#   'verbas',
#   'construção',
#   'usina',
#   'hidrelétrica',
#   'Cotingo',
#   'ajuda',
#   'financeira',
#   'dar',
#   'continuidade',
#   'obras',
#   'iniciadas',
#   'antecessor'],
#  ['julho',
#   '1995',
#   'artigo',
#   'publicado',
#   'jornal',
#   '«',
#   'Estado',
#   'S.',
#   'Paulo',
#   '»',
#   'manifestou-se',
#   'contrário',
#   'proposta',
#   'diminuição',
#   'número',
#   'parlamentares',
#   'apresentada',
#   'deputado',
#   'José',
#   'Genoíno',
#   'Partido',
#   'Trabalhadores',
#   'PT',
#   'resultaria',
#   'perda',
#   'representação',
#   'estados',
#   'nortistas',
#   'apontando-a',
#   'demonstrativa',
#   'visão',
#   'caolha'],
#  ['Contestou',
#   'afirmação',
#   'Genoíno',
#   'haveria',
#   'apenas',
#   'políticos',
#   'conservadores',
#   'clientelistas',
#   'estados',
#   'Norte',
#   'citando',
#   'exemplo',
#   'bancadas',
#   'esquerda',
#   'expressivas',
#   'Acre',
#   'incluía',
#   'senadora',
#   'filiada',
#   'PT',
#   'Amapá',
#   'cujo',
#   'governador',
#   'filiado',
#   'Partido',
#   'Socialista',
#   'Brasileiro',
#   'PSB'],
#  ['setembro',
#   '1995',
#   'admitiu',
#   'Roraima',
#   'sete',
#   'anos',
#   'tornar',
#   'estado',
#   'ainda',
#   'vivia',
#   'custa',
#   'União',
#   'afirmar',
#   'verbas',
#   'federais',
#   'estado',
#   'quebra'],
#  ['mês',
#   'anunciou',
#   'investimento',
#   '15',
#   'milhões',
#   'reais',
#   'asfaltar',
#   'BR-174',
#   'fronteira',
#   'Amazonas',
#   'obra',
#   'fundamental',
#   'ponto',
#   'vista',
#   'transformar',
#   'Roraima',
#   'grande',
#   'corredor',
#   'exportação',
#   'rumo',
#   'mercados',
#   'Caribe',
#   'Nafta'],
#  ['final',
#   'janeiro',
#   '1998',
#   'decretou',
#   'estado',
#   'calamidade',
#   'pública',
#   'Roraima',
#   'devido',
#   'seca',
#   'prolongada',
#   'falta',
#   'água',
#   'potável',
#   'situação',
#   'levaria',
#   'estado',
#   'enfrentar',
#   'piores',
#   'incêndios',
#   'história',
#   'durante',
#   'três',
#   'meses',
#   'causando',
#   'devastação',
#   'quase',
#   'dez',
#   'mil',
#   'metros',
#   'quadrados',
#   'floresta'],
#  ['auxílio',
#   'governo',
#   'federal',
#   'chegou',
#   'meados',
#   'março',
#   'criticou',
#   'presidente',
#   'Fernando',
#   'Henrique',
#   'Cardoso',
#   'tê-lo',
#   'ajudado',
#   'desde',
#   'início',
#   'combater',
#   'catástrofe'],
#  ['mês',
#   'junho',
#   'veio',
#   'tona',
#   'amplo',
#   'esquema',
#   'corrupção',
#   'montado',
#   'interior',
#   'Companhia',
#   'Desenvolvimento',
#   'Roraima',
#   'Condesaima',
#   'desde',
#   'início',
#   'administração'],
#  ['denúncias',
#   'veiculadas',
#   'Ronald',
#   'Jorge',
#   'P.',
#   'Santos',
#   'Filho',
#   'envolvidos',
#   'trama',
#   'assim',
#   'agiu',
#   'sentir-se',
#   'traído',
#   'incriminavam',
#   'diretamente',
#   'dois',
#   'concunhados',
#   'governador',
#   'criado',
#   'empresa-fantasma',
#   'supostamente',
#   'destinada',
#   'fornecer',
#   'produtos',
#   'Condesaima',
#   'outros',
#   'órgãos',
#   'públicos'],
#  ['testa-de-ferro',
#   'Ronald',
#   'Jorge',
#   'apresentava',
#   'notas',
#   'fiscais',
#   'frias',
#   'realmente',
#   'fornecendo',
#   'produtos'],
#  ['receber', 'dinheiro', 'devolvia-o', 'contraparentes', 'governador'],
#  ['setembro',
#   'jornal',
#   '«',
#   'Globo',
#   '»',
#   'divulgou',
#   'matéria',
#   'revelando',
#   'existência',
#   'conjunto',
#   'fitas',
#   'contendo',
#   'gravações',
#   'conversas',
#   'Neudo',
#   'Campos',
#   'serviria',
#   'base',
#   'denúncia',
#   'desvio',
#   'recursos',
#   'órgãos',
#   'estatais',
#   'campanha',
#   'reeleição'],
#  ['teor',
#   'conversas',
#   'comprometia',
#   'secretário',
#   'Fazenda',
#   'Roberto',
#   'Leonel',
#   'chefe',
#   'Gabinete',
#   'Civil',
#   'Cilene',
#   'Salomão',
#   'acusada',
#   'articular',
#   'operações',
#   'triangulação',
#   'distribuição',
#   'recursos',
#   'campanha',
#   'parentes',
#   'governador',
#   'ocupavam',
#   'cargos',
#   'direção',
#   'Condesaima'],
#  ['acordo',
#   'gravações',
#   'dinheiro',
#   'desviado',
#   'Secretaria',
#   'Fazenda',
#   'repassado',
#   'Condesaima',
#   'vez',
#   'incumbência',
#   'entregar',
#   'pacotes',
#   'cédulas',
#   'assessores',
#   'governador'],
#  ['Durante',
#   'investigações',
#   'juiz',
#   'primeira',
#   'inst',
#   "''",
#   'ncia',
#   'Hélder',
#   'Girão',
#   'Barreto',
#   'julgou',
#   'procedente',
#   'ação',
#   'popular',
#   'requerendo',
#   'demissão',
#   '17',
#   'parentes',
#   'governador',
#   'sob',
#   'acusação',
#   'desviarem',
#   'recursos',
#   'públicos',
#   'campanha',
#   'criarem',
#   'empresas-fantasmas',
#   'fornecer',
#   'suprimentos',
#   'Condesaima',
#   'determinou',
#   'ainda',
#   'demissão',
#   'todos',
#   'parentes',
#   'desembargadores',
#   'lotavam',
#   'Tribunal',
#   'Justiça',
#   'Roraima'],
#  ['Além',
#   'disso',
#   'deu',
#   'parecer',
#   'favorável',
#   'pedido',
#   'quebra',
#   'sigilo',
#   'bancário',
#   'oito',
#   'auxiliares',
#   'governador',
#   'estariam',
#   'ponta',
#   'esquema',
#   'corrupção',
#   'denunciado',
#   'Ronald',
#   'Jorge'],
#  ['resultado',
#   'decisão',
#   'além',
#   'afastado',
#   'funções',
#   'exercia',
#   'alvo',
#   'processo',
#   'administrativo',
#   'supostas',
#   'faltas',
#   'disciplinares',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'todas',
#   'decisões',
#   'cassadas',
#   'Tribunal',
#   'Justiça',
#   'estado'],
#  ['parentes',
#   'acusados',
#   'governador',
#   'demitidos',
#   'devido',
#   'proporções',
#   'atingidas',
#   'esc',
#   "''",
#   'ndalo'],
#  ['conta',
#   'disso',
#   'Supremo',
#   'Tribunal',
#   'Federal',
#   'STF',
#   'acabou',
#   'intervir',
#   'Tribunal',
#   'Justiça',
#   'Roraima',
#   'suspeito',
#   'tentar',
#   'obstruir',
#   'investigação',
#   'denúncias',
#   'corrupção',
#   'nepotismo',
#   'contra',
#   'governador',
#   'reintegrar',
#   'unanimidade',
#   'juiz',
#   'Hélder',
#   'Barreto',
#   'decidir',
#   'cinco',
#   'seis',
#   'desembargadores',
#   'daquela',
#   'corte',
#   'impedidos',
#   'julgar',
#   'mandado',
#   'segurança',
#   'impetrado',
#   'haviam',
#   'tido',
#   'parentes',
#   'demitidos',
#   'tribunal',
#   'decisão',
#   'juiz'],
#  ['despeito',
#   'tais',
#   'denúncias',
#   'Neudo',
#   'Campos',
#   'disputou',
#   'êxito',
#   'reeleição',
#   'outubro',
#   '1998',
#   'frente',
#   'coligação',
#   'integrada',
#   'partido',
#   'Partido',
#   'Progressista',
#   'Brasileiro',
#   'PPB',
#   'ainda',
#   'Partido',
#   'Liberal',
#   'PL',
#   'Partido',
#   'Democrático',
#   'Trabalhista',
#   'PDT',
#   'além',
#   'agremiações',
#   'menores'],
#  ['principais',
#   'adversárias',
#   'ex-prefeita',
#   'Boa',
#   'Vista',
#   'Teresa',
#   'Jucá',
#   'senadora',
#   'Marluce',
#   'Pinto',
#   'Partido',
#   'Movimento',
#   'Democrático',
#   'Brasileiro',
#   'PMDB',
#   'cujo',
#   'marido',
#   'Otomar',
#   'Pinto',
#   'prefeito',
#   'Boa',
#   'Vista',
#   'rompeu',
#   'decidiu',
#   'concorrer',
#   'reeleição'],
#  ['Iniciou',
#   'segundo',
#   'governo',
#   '1º',
#   'janeiro',
#   '1999',
#   '2000',
#   'deixou',
#   'PPB',
#   'filiou-se',
#   'Partido',
#   'Frente',
#   'Liberal',
#   'PFL'],
#  ['janeiro',
#   '2003',
#   'encerrou',
#   'governo',
#   'deixou',
#   'PFL',
#   'filiou-se',
#   'Partido',
#   'Progressista',
#   'PP'],
#  ['2005',
#   '2006',
#   'secretário',
#   'Governo',
#   'Roraima',
#   'gestão',
#   'Otomar',
#   'Pinto',
#   '2004-2007'],
#  ['Nesse',
#   'último',
#   'ano',
#   'concorreu',
#   'êxito',
#   'eleições',
#   'deputado',
#   'federal',
#   'legenda',
#   'PP'],
#  ['Assumindo',
#   'mandato',
#   'C',
#   "''",
#   'mara',
#   'fevereiro',
#   '2007',
#   'tornou-se',
#   'membro',
#   'titular',
#   'comissões',
#   'Amazônia',
#   'Integração',
#   'Nacional',
#   'Desenvolvimento',
#   'Regional',
#   'Minas',
#   'Energia'],
#  ['Casou-se',
#   'Sueli',
#   'Campos',
#   'deputada',
#   'federal',
#   'Roraima',
#   '2003',
#   '2007',
#   'vice-prefeita',
#   'Rio',
#   'Branco',
#   'partir',
#   '2009',
#   'quatro',
#   'filhos']]
