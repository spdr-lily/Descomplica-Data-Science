# %% [markdown]
# <a href="https://colab.research.google.com/github/spdr-lily/Data-Science-Profile/blob/main/ANALISE_INTERPRETACAO_LINGUAGEM_NATURAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processamento de Linguagem Natural
# Análise e Interpretação da Linguagem Natural

# %% [markdown]
# # Baixando a legenda

# %%
! wget -O breaking-bad-s01e01.txt https://gist.githubusercontent.com/alvelvis/e08b9a85796ca4bbfb6a71cfadf3b291/raw/74efcee1d9fa98dc13893ed67b1e6d9cef075548/breaking-bad-subtitles-pt-s01ep01
# Out:
# --2025-05-05 19:10:37--  https://gist.githubusercontent.com/alvelvis/e08b9a85796ca4bbfb6a71cfadf3b291/raw/74efcee1d9fa98dc13893ed67b1e6d9cef075548/breaking-bad-subtitles-pt-s01ep01
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40171 (39K) [text/plain]
# Saving to: ‘breaking-bad-s01e01.txt’
#
# breaking-bad-s01e01 100%[===================>]  39.23K  --.-KB/s    in 0.01s
#
# 2025-05-05 19:10:37 (3.27 MB/s) - ‘breaking-bad-s01e01.txt’ saved [40171/40171]

# %% [markdown]
# # Abrindo a legenda e entendendo sua estrutura

# %%
with open("breaking-bad-s01e01.txt") as f:
    legenda = f.read()

# %%
print(legenda)
# Out:
# 2
# 00:00:06,855 --> 00:00:09,464
# Esteja o telespectador ciente.
#
# 3
# 00:02:14,030 --> 00:02:16,220
# Meu nome é Walter Hartwell White,
#
# 4
# 00:02:16,230 --> 00:02:19,107
# moro na Alameda Riacho Negro, 308
#
# 5
# 00:02:19,142 --> 00:02:21,670
# Cidade de Albuquerque,
# no Novo México, CEP 87104.
#
# 6
# 00:02:21,680 --> 00:02:25,110
# Para as entidades de imposição
# da lei, isso não é uma confissão.
#
# 7
# 00:02:25,770 --> 00:02:28,530
# Estou falando para
# minha família agora.
#
# 8
# 00:02:35,860 --> 00:02:40,160
# Skyler...
# você é o amor da minha vida.
#
# 9
# 00:02:40,170 --> 00:02:42,090
# Espero que saiba disso.
#
# 10
# 00:02:43,460 --> 00:02:47,320
# Walter Júnior...
# você é o meu rapazão.
#
# 11
# 00:02:48,270 --> 00:02:51,718
# Hav...Haverá algumas...
#
# 12
# 00:02:52,060 --> 00:02:54,121
# coisas... coisas...
#
# 13
# 00:02:54,260 --> 00:02:57,966
# que vocês descobrirão sobre
# mim logo...em poucos dias.
#
# 14
# 00:02:58,001 --> 00:03:00,700
# ...

# %% [markdown]
# # Transformando a legenda em um só texto

# %%
falas = legenda.split("\n\n")

# %%
falas
# Out:
# ['2\n00:00:06,855 --> 00:00:09,464\nEsteja o telespectador ciente.',
#  '3\n00:02:14,030 --> 00:02:16,220\nMeu nome é Walter Hartwell White,',
#  '4\n00:02:16,230 --> 00:02:19,107\nmoro na Alameda Riacho Negro, 308',
#  '5\n00:02:19,142 --> 00:02:21,670\nCidade de Albuquerque,\nno Novo México, CEP 87104.',
#  '6\n00:02:21,680 --> 00:02:25,110\nPara as entidades de imposição\nda lei, isso não é uma confissão.',
#  '7\n00:02:25,770 --> 00:02:28,530\nEstou falando para\nminha família agora.',
#  '8\n00:02:35,860 --> 00:02:40,160\nSkyler...\nvocê é o amor da minha vida.',
#  '9\n00:02:40,170 --> 00:02:42,090\nEspero que saiba disso.',
#  '10\n00:02:43,460 --> 00:02:47,320\nWalter Júnior...\nvocê é o meu rapazão.',
#  '11\n00:02:48,270 --> 00:02:51,718\nHav...Haverá algumas...',
#  '12\n00:02:52,060 --> 00:02:54,121\ncoisas... coisas...',
#  '13\n00:02:54,260 --> 00:02:57,966\nque vocês descobrirão sobre\nmim logo...em poucos dias.',
# ...

# %%
falas[0]
# Out:
# '2\n00:00:06,855 --> 00:00:09,464\nEsteja o telespectador ciente.'

# %%
falas[0].split("\n", 2)
# Out:
# ['2', '00:00:06,855 --> 00:00:09,464', 'Esteja o telespectador ciente.']

# %%
falas[0].split("\n", 2)[2]
# Out:
# 'Esteja o telespectador ciente.'

# %%
texto = ""

for fala in falas:
    texto = texto + " " + fala.split("\n", 2)[2]

# %%
texto
# Out:
# ' Esteja o telespectador ciente. Meu nome é Walter Hartwell White, moro na Alameda Riacho Negro, 308 Cidade de Albuquerque,\nno Novo México, CEP 87104. Para as entidades de imposição\nda lei, isso não é uma confissão. Estou falando para\nminha família agora. Skyler...\nvocê é o amor da minha vida. Espero que saiba disso. Walter Júnior...\nvocê é o meu rapazão. Hav...Haverá algumas... coisas... coisas... que vocês descobrirão sobre\nmim logo...em poucos dias. Só quero que vocês saibam que não... não importa o que isso pareça,\neu só tenho vocês no meu coração. Adeus. <b>Tradução, e revisão:\nRicardoMica e Cida</b> <b>Ressync para o BluRay:\nz MooReTi ll</b> Três semanas antes Prêmio Nobel em 1985 por desenvolver\na radiografia por prótons. Feliz Aniversário. Olha isso. Isto é bacon vegetariano... acredite ou não. Zero de colesterol. Você não perceberá\ndiferença no sabor. Que horas você acha\nque voltará pra casa? No mesmo de sempre. Eu não quero você\ncansado esta noite. Você ganha p
# ...

# %% [markdown]
# # Limpando a legenda

# %%
texto = texto.replace("\n", " ")
texto = texto.replace("<b>", "")
texto = texto.replace("</b>", "")
texto = texto.replace("<i>", "")
texto = texto.replace("</i>", "")

# %%
texto
# Out:
# ' Esteja o telespectador ciente. Meu nome é Walter Hartwell White, moro na Alameda Riacho Negro, 308 Cidade de Albuquerque, no Novo México, CEP 87104. Para as entidades de imposição da lei, isso não é uma confissão. Estou falando para minha família agora. Skyler... você é o amor da minha vida. Espero que saiba disso. Walter Júnior... você é o meu rapazão. Hav...Haverá algumas... coisas... coisas... que vocês descobrirão sobre mim logo...em poucos dias. Só quero que vocês saibam que não... não importa o que isso pareça, eu só tenho vocês no meu coração. Adeus. Tradução, e revisão: RicardoMica e Cida Ressync para o BluRay: z MooReTi ll Três semanas antes Prêmio Nobel em 1985 por desenvolver a radiografia por prótons. Feliz Aniversário. Olha isso. Isto é bacon vegetariano... acredite ou não. Zero de colesterol. Você não perceberá diferença no sabor. Que horas você acha que voltará pra casa? No mesmo de sempre. Eu não quero você cansado esta noite. Você ganha pra trabalhar 5 horas, traba
# ...

# %% [markdown]
# # Segmentando frases

# %%
frases = texto.split(". ")

# %%
frases
# Out:
# [' Esteja o telespectador ciente',
#  'Meu nome é Walter Hartwell White, moro na Alameda Riacho Negro, 308 Cidade de Albuquerque, no Novo México, CEP 87104',
#  'Para as entidades de imposição da lei, isso não é uma confissão',
#  'Estou falando para minha família agora',
#  'Skyler..',
#  'você é o amor da minha vida',
#  'Espero que saiba disso',
#  'Walter Júnior..',
#  'você é o meu rapazão',
#  'Hav...Haverá algumas..',
#  'coisas..',
#  'coisas..',
#  'que vocês descobrirão sobre mim logo...em poucos dias',
#  'Só quero que vocês saibam que não..',
#  'não importa o que isso pareça, eu só tenho vocês no meu coração',
#  'Adeus',
#  'Tradução, e revisão: RicardoMica e Cida Ressync para o BluRay: z MooReTi ll Três semanas antes Prêmio Nobel em 1985 por desenvolver a radiografia por prótons',
#  'Feliz Aniversário',
#  'Olha isso',
#  'Isto é bacon vegetariano..',
#  'acredite ou não',
#  'Zero de colesterol',
#  'Você não perceberá diferença no sabor',
# ...

# %%
frases = [frase + "." for frase in frases]

# %%
frases
# Out:
# [' Esteja o telespectador ciente.',
#  'Meu nome é Walter Hartwell White, moro na Alameda Riacho Negro, 308 Cidade de Albuquerque, no Novo México, CEP 87104.',
#  'Para as entidades de imposição da lei, isso não é uma confissão.',
#  'Estou falando para minha família agora.',
#  'Skyler...',
#  'você é o amor da minha vida.',
#  'Espero que saiba disso.',
#  'Walter Júnior...',
#  'você é o meu rapazão.',
#  'Hav...Haverá algumas...',
#  'coisas...',
#  'coisas...',
#  'que vocês descobrirão sobre mim logo...em poucos dias.',
#  'Só quero que vocês saibam que não...',
#  'não importa o que isso pareça, eu só tenho vocês no meu coração.',
#  'Adeus.',
#  'Tradução, e revisão: RicardoMica e Cida Ressync para o BluRay: z MooReTi ll Três semanas antes Prêmio Nobel em 1985 por desenvolver a radiografia por prótons.',
#  'Feliz Aniversário.',
#  'Olha isso.',
#  'Isto é bacon vegetariano...',
#  'acredite ou não.',
#  'Zero de colesterol.',
#  'Você não perceberá diferença no sabor.',
# ...

# %% [markdown]
# # Segmentando tokens

# %%
# List comprehension: laço de repetição (loop) dentro de uma lista para gerar outra lista
frases = [frase\
          .replace(".", " . ")\
          .replace(",", " , ")\
          .replace("!", " ! ")\
          .replace("?", " ? ")\
          .replace(":", " : ")\
          .replace("  ", " ")\
          .strip() for frase in frases]

# %%
frases
# Out:
# ['Esteja o telespectador ciente .',
#  'Meu nome é Walter Hartwell White , moro na Alameda Riacho Negro , 308 Cidade de Albuquerque , no Novo México , CEP 87104 .',
#  'Para as entidades de imposição da lei , isso não é uma confissão .',
#  'Estou falando para minha família agora .',
#  'Skyler . . .',
#  'você é o amor da minha vida .',
#  'Espero que saiba disso .',
#  'Walter Júnior . . .',
#  'você é o meu rapazão .',
#  'Hav . . . Haverá algumas . . .',
#  'coisas . . .',
#  'coisas . . .',
#  'que vocês descobrirão sobre mim logo . . . em poucos dias .',
#  'Só quero que vocês saibam que não . . .',
#  'não importa o que isso pareça , eu só tenho vocês no meu coração .',
#  'Adeus .',
#  'Tradução , e revisão : RicardoMica e Cida Ressync para o BluRay : z MooReTi ll Três semanas antes Prêmio Nobel em 1985 por desenvolver a radiografia por prótons .',
#  'Feliz Aniversário .',
#  'Olha isso .',
#  'Isto é bacon vegetariano . . .',
#  'acredite ou não .',
# ...

# %%
frases_tokenizadas = [frase.split(" ") for frase in frases]

# %%
frases_tokenizadas
# Out:
# [['Esteja', 'o', 'telespectador', 'ciente', '.'],
#  ['Meu',
#   'nome',
#   'é',
#   'Walter',
#   'Hartwell',
#   'White',
#   ',',
#   'moro',
#   'na',
#   'Alameda',
#   'Riacho',
#   'Negro',
#   ',',
#   '308',
#   'Cidade',
#   'de',
#   'Albuquerque',
#   ',',
#   'no',
#   'Novo',
#   'México',
#   ',',
#   'CEP',
#   '87104',
#   '.'],
#  ['Para',
#   'as',
#   'entidades',
#   'de',
#   'imposição',
#   'da',
#   'lei',
#   ',',
#   'isso',
#   'não',
#   'é',
#   'uma',
#   'confissão',
#   '.'],
#  ['Estou', 'falando', 'para', 'minha', 'família', 'agora', '.'],
#  ['Skyler', '.', '.', '.'],
#  ['você', 'é', 'o', 'amor', 'da', 'minha', 'vida', '.'],
#  ['Espero', 'que', 'saiba', 'disso', '.'],
#  ['Walter', 'Júnior', '.', '.', '.'],
#  ['você', 'é', 'o', 'meu', 'rapazão', '.'],
#  ['Hav', '.', '.', '.', 'Haverá', 'algumas', '.', '.', '.'],
#  ['coisas', '.', '.', '.'],
#  ['coisas', '.', '.', '.'],
#  ['que',
#   'vocês',
#   'descobrirão',
#   'sobre',
#   'mim',
# ...

# %%
frases_tokenizadas[0]
# Out:
# ['Esteja', 'o', 'telespectador', 'ciente', '.']

# %% [markdown]
# # Gerando lista de palavras-chave usando YAKE

# %%
! pip3 install yake
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.9/356.9 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import yake

# %%
texto
# Out:
# ' Esteja o telespectador ciente. Meu nome é Walter Hartwell White, moro na Alameda Riacho Negro, 308 Cidade de Albuquerque, no Novo México, CEP 87104. Para as entidades de imposição da lei, isso não é uma confissão. Estou falando para minha família agora. Skyler... você é o amor da minha vida. Espero que saiba disso. Walter Júnior... você é o meu rapazão. Hav...Haverá algumas... coisas... coisas... que vocês descobrirão sobre mim logo...em poucos dias. Só quero que vocês saibam que não... não importa o que isso pareça, eu só tenho vocês no meu coração. Adeus. Tradução, e revisão: RicardoMica e Cida Ressync para o BluRay: z MooReTi ll Três semanas antes Prêmio Nobel em 1985 por desenvolver a radiografia por prótons. Feliz Aniversário. Olha isso. Isto é bacon vegetariano... acredite ou não. Zero de colesterol. Você não perceberá diferença no sabor. Que horas você acha que voltará pra casa? No mesmo de sempre. Eu não quero você cansado esta noite. Você ganha pra trabalhar 5 horas, traba
# ...

# %%
kw_extractor = yake.KeywordExtractor(lan="pt", n=1)
keywords = kw_extractor.extract_keywords(texto)

# %%
keywords
# Out:
# [('pra', np.float64(0.010876360762049285)),
#  ('vamos', np.float64(0.020562366676107287)),
#  ('mesmo', np.float64(0.02347742045836261)),
#  ('cara', np.float64(0.025848151840182465)),
#  ('Walt', np.float64(0.03314696094928329)),
#  ('White', np.float64(0.035723815591046634)),
#  ('Certo', np.float64(0.03761973232367006)),
#  ('Walter', np.float64(0.03895479458289145)),
#  ('Vou', np.float64(0.040811734800775316)),
#  ('Deus', np.float64(0.0457247008486225)),
#  ('Então', np.float64(0.04590689804849116)),
#  ('casa', np.float64(0.04962112915624713)),
#  ('Química', np.float64(0.05853667866853804)),
#  ('fora', np.float64(0.0606146561672034)),
#  ('laboratório', np.float64(0.0664823178703304)),
#  ('verdade', np.float64(0.06783567210565163)),
#  ('produzir', np.float64(0.06998913433504923)),
#  ('seja', np.float64(0.0715109523746074)),
#  ('Bagulho', np.float64(0.0843333417817622)),
#  ('normal', np.float64(0.0851470964961768))]

# %%
sorted(keywords, key=lambda x: x[1], reverse=True)
# Out:
# [('normal', np.float64(0.0851470964961768)),
#  ('Bagulho', np.float64(0.0843333417817622)),
#  ('seja', np.float64(0.0715109523746074)),
#  ('produzir', np.float64(0.06998913433504923)),
#  ('verdade', np.float64(0.06783567210565163)),
#  ('laboratório', np.float64(0.0664823178703304)),
#  ('fora', np.float64(0.0606146561672034)),
#  ('Química', np.float64(0.05853667866853804)),
#  ('casa', np.float64(0.04962112915624713)),
#  ('Então', np.float64(0.04590689804849116)),
#  ('Deus', np.float64(0.0457247008486225)),
#  ('Vou', np.float64(0.040811734800775316)),
#  ('Walter', np.float64(0.03895479458289145)),
#  ('Certo', np.float64(0.03761973232367006)),
#  ('White', np.float64(0.035723815591046634)),
#  ('Walt', np.float64(0.03314696094928329)),
#  ('cara', np.float64(0.025848151840182465)),
#  ('mesmo', np.float64(0.02347742045836261)),
#  ('vamos', np.float64(0.020562366676107287)),
#  ('pra', np.float64(0.010876360762049285))]

# %% [markdown]
# # Gerando lista de palavras-chave usando SPACY

# %%
! pip3 install spacy

# %%
! python3 -m spacy download pt_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 98.8 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp = spacy.load("pt_core_news_sm")
doc = nlp(texto)

# %%
for token in set(doc.ents):
    print(token)
# Out:
# Deus
# Ei
# Marte
# Química
# Sim
# Normal
# Hank
# Beleza
# Continue
# Walter
# Emílio
# Continue
# Carmen
# Winnebago
# Normal
# Acho
# Mamãe
# Walt
# Pensei
# Prêmio Nobel
# Te vejo
# Polícia
# Walter
# Tomei
# Coma
# Apostado
# Conte-me
# Rola
# Aposto
# Espere!
# Adeus
# Ei
# Ok
# Pinkman
# Los Alamos
# bilionésima
# Sim
# Walter
# Digo
# Walter
# Jesus
# Curral
# Prof
# Fico
# Hank
# Jesus
# Judas
# BluRay
# Deus
# Desculpa
# Vou te arrebentar
# Saúde
# Bogdan
# Hank
# Doideira...
# Nem
# Negocie
# Cida Ressync
# Walt
# Respire
# Certo?
# Lalique
# Alameda Riacho Negro
# Capitão Bagulho
# Federal
# Sei
# Alguém
# Raríssimo
# Produzir
# Glock
# Jesus
# Capitão Bagulho
# Tenho
# Aonde
# Crystals
# Walter Hartwell White
# Inoperável
# Pardal
# Saúde
# Feche
# Novo México
# Verdade
# Faça
# Olha
# Certa
# Volte
# Moléculas
# Jesse
# Tô
# Emílio
# Zero
# US$
# Meu Deus
# Emilio
# Sr. White
# Continue
# Química
# Walt
# Legal
# Capitão Bagulho
# MooReTi
# Keith Richards
# Emilio
# ...
