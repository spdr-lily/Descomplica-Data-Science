# %% [markdown]
# <a href="https://colab.research.google.com/github/spdr-lily/Data-Science-Profile/blob/main/PLN_sumarizacao_de_textos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processamento de Linguagem Natural
# Sumarização de Textos

# %% [markdown]
# # Baixando página da Wikipedia

# %%
! pip3 install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=c29659c3b3d0c45674357fcb72db5f5ce115330eb83718af183920917f0d4489
#   Stored in directory: /root/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# ...

# %%
import wikipedia
wikipedia.set_lang("pt")

# %%
documento = wikipedia.page("Brasil")

# %%
documento.title
# Out:
# 'Brasil'

# %%
documento.content
# Out:
# 'Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com cerca de 8,5 milhões de quilômetros quadrados, e o sétimo em população (com 212 milhões de habitantes, em julho de 2024). É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo. Sua atual constituição, promulgada em 1988, concebe o Brasil como uma república federativa presidencialista, formada pela união de 26 estados, do Distrito Federal e dos 5 571 municípios.\nBanhado pelo Oceano Atlântico, o Brasil tem um litoral de 7 491 km e faz fronteira com todos os outros países sul-americanos, exceto Chile e Equador, sendo limitado a norte pela Venezue
# ...

# %%
documento = documento.content
documento = documento.replace("(? escutar)", "")
documento = documento.replace("\n", " ")

# %% [markdown]
# # Usando NLTK para segmentar os documentos

# %%
import nltk
import string
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download("punkt_tab")
nltk.download("stopwords")
stopwords = nltk.corpus.stopwords.words('portuguese')
punctuation = string.punctuation
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
tokens = word_tokenize(documento)

# %%
print(tokens)
# Out:
# ['Brasil', '(', 'localmente', '[', 'bɾaˈziw', ']', ')', ',', 'oficialmente', 'República', 'Federativa', 'do', 'Brasil', '(', ')', ',', 'é', 'o', 'maior', 'país', 'da', 'América', 'do', 'Sul', 'e', 'da', 'região', 'da', 'América', 'Latina', ',', 'sendo', 'o', 'quinto', 'maior', 'do', 'mundo', 'em', 'área', 'territorial', '(', 'equivalente', 'a', '47,3', '%', 'do', 'território', 'sul-americano', ')', ',', 'com', 'cerca', 'de', '8,5', 'milhões', 'de', 'quilômetros', 'quadrados', ',', 'e', 'o', 'sétimo', 'em', 'população', '(', 'com', '212', 'milhões', 'de', 'habitantes', ',', 'em', 'julho', 'de', '2024', ')', '.', 'É', 'o', 'único', 'país', 'na', 'América', 'onde', 'se', 'fala', 'majoritariamente', 'a', 'língua', 'portuguesa', 'e', 'o', 'maior', 'país', 'lusófono', 'do', 'planeta', ',', 'além', 'de', 'ser', 'uma', 'das', 'nações', 'mais', 'multiculturais', 'e', 'etnicamente', 'diversas', ',', 'em', 'decorrência', 'da', 'forte', 'imigração', 'oriunda', 'de', 'variados', 'locais', 'do', '
# ...

# %% [markdown]
# # Usando NLTK para obter a "raíz" das palavras

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer("portuguese")

# %%
raizes = []

for token in tokens:
    if not token in punctuation and not token in stopwords:
        raizes.append(stemmer.stem(token))

# %%
print(raizes)
# Out:
# ['brasil', 'local', 'bɾaˈziw', 'oficial', 'repúbl', 'feder', 'brasil', 'maior', 'país', 'amér', 'sul', 'regiã', 'amér', 'latin', 'send', 'quint', 'maior', 'mund', 'áre', 'territorial', 'equivalent', '47,3', 'territóri', 'sul-american', 'cerc', '8,5', 'milhõ', 'quilômetr', 'quadr', 'sétim', 'popul', '212', 'milhõ', 'habit', 'julh', '2024', 'é', 'únic', 'país', 'amér', 'onde', 'fal', 'majoritari', 'língu', 'portugues', 'maior', 'país', 'lusófon', 'planet', 'além', 'naçõ', 'multicultur', 'etnic', 'divers', 'decorrent', 'fort', 'imigr', 'oriund', 'vari', 'loc', 'mund', 'sua', 'atual', 'constituiçã', 'promulg', '1988', 'conceb', 'brasil', 'repúbl', 'feder', 'presidencial', 'form', 'uniã', '26', 'estad', 'distrit', 'federal', '5', '571', 'municípi', 'banh', 'ocean', 'atlânt', 'brasil', 'litoral', '7', '491', 'km', 'faz', 'fronteir', 'tod', 'outr', 'país', 'sul-american', 'excet', 'chil', 'equador', 'send', 'limit', 'nort', 'venezuel', 'guian', 'surinam', 'depart', 'ultramarin', 'francês', 
# ...

# %%
print(len(raizes))
print(len(set(raizes)))
# Out:
# 8283
# 2766

# %% [markdown]
# # Contando as raízes mais frequentes

# %%
frequencia_das_raizes = {
    raiz: raizes.count(raiz) for raiz in set(raizes)
    }

# %%
print(sorted(frequencia_das_raizes.items(), key=lambda x: x[1], reverse=True))
# Out:
# [('brasil', 136), ('país', 114), ('brasileir', 113), ('o', 87), ('a', 84), ('maior', 83), ('===', 76), ('estad', 58), ('part', 49), ('tod', 42), ('federal', 40), ('outr', 38), ('sul', 37), ('primeir', 36), ('em', 35), ('grand', 35), ('pod', 33), ('nacional', 33), ('mund', 32), ('amér', 32), ('popul', 31), ('polít', 31), ('send', 30), ('govern', 30), ('os', 27), ('portugues', 26), ('rio', 25), ('sécul', 25), ('milit', 25), ('==', 24), ('no', 23), ('sistem', 23), ('janeir', 22), ('unid', 21), ('guerr', 21), ('segund', 21), ('sã', 21), ('nov', 20), ('constituiçã', 20), ('municípi', 20), ('territóri', 19), ('anos', 19), ('habit', 19), ('forc', 19), ('indígen', 18), ('após', 18), ('paul', 18), ('president', 18), ('econôm', 18), ('déc', 17), ('vez', 17), ('períod', 16), ('inclu', 16), ('europ', 16), ('portugal', 16), ('acord', 16), ('mil', 16), ("''", 16), ('aind', 16), ('form', 16), ('latin', 16), ('``', 15), ('língu', 15), ('principal', 15), ('organiz', 15), ('durant', 15), ('milhõ', 15)
# ...

# %%
del frequencia_das_raizes["==="]
del frequencia_das_raizes["=="]
del frequencia_das_raizes["''"]
del frequencia_das_raizes["``"]

# %% [markdown]
# # Rankeando as frases do documento

# %%
frases = sent_tokenize(documento)

# %%
print(frases)
# Out:
# ['Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com cerca de 8,5 milhões de quilômetros quadrados, e o sétimo em população (com 212 milhões de habitantes, em julho de 2024).', 'É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo.', 'Sua atual constituição, promulgada em 1988, concebe o Brasil como uma república federativa presidencialista, formada pela união de 26 estados, do Distrito Federal e dos 5 571 municípios.', 'Banhado pelo Oceano Atlântico, o Brasil tem um litoral de 7 491 km e faz fronteira com todos os outros países sul-americanos, exceto Chile e Equador, sendo limitado a norte pel
# ...

# %%
ranking_frases = []

for frase in frases:
    pontos = 0
    tokens = word_tokenize(frase)
    raizes = [stemmer.stem(token) for token in tokens]
    for raiz in raizes:
        pontos += frequencia_das_raizes.get(raiz, 0)
    ranking_frases.append(pontos / len(tokens))

# %%
print(ranking_frases)
# Out:
# [18.766233766233768, 18.644444444444446, 15.93939393939394, 13.75, 15.7, 16.703703703703702, 19.296296296296298, 7.925, 10.264705882352942, 13.261904761904763, 25.466666666666665, 25.529411764705884, 13.515625, 16.76923076923077, 7.424242424242424, 23.210526315789473, 17.440677966101696, 16.88235294117647, 8.962264150943396, 11.4375, 4.722222222222222, 6.848484848484849, 13.2, 9.95, 15.368421052631579, 19.821428571428573, 16.366666666666667, 11.758620689655173, 12.964285714285714, 10.066666666666666, 9.971014492753623, 5.121212121212121, 9.296296296296296, 9.74074074074074, 8.342857142857143, 14.088235294117647, 14.090909090909092, 17.375, 10.066666666666666, 16.435897435897434, 13.827586206896552, 14.222222222222221, 11.912280701754385, 12.295918367346939, 12.768115942028986, 13.979166666666666, 19.130434782608695, 20.535714285714285, 14.022727272727273, 17.533333333333335, 13.074074074074074, 11.610169491525424, 19.157894736842106, 20.885714285714286, 18.18918918918919, 13.92592592
# ...

# %% [markdown]
# # Retornando as frases com pontuação acima da média

# %%
media_de_pontos = sum(ranking_frases) / len(ranking_frases)
media_de_pontos
# Out:
# 15.256287780050222

# %%
resumo = []
for i, frase in enumerate(frases):
    pontos = ranking_frases[i]
    if pontos > (1.2 * media_de_pontos):
        resumo.append(frase)
    if len(resumo) == 5:
        resumo = " ".join(resumo)
        break

# %%
resumo
# Out:
# 'Brasil (localmente [bɾaˈziw]), oficialmente República Federativa do Brasil (), é o maior país da América do Sul e da região da América Latina, sendo o quinto maior do mundo em área territorial (equivalente a 47,3% do território sul-americano), com cerca de 8,5 milhões de quilômetros quadrados, e o sétimo em população (com 212 milhões de habitantes, em julho de 2024). É o único país na América onde se fala majoritariamente a língua portuguesa e o maior país lusófono do planeta, além de ser uma das nações mais multiculturais e etnicamente diversas, em decorrência da forte imigração oriunda de variados locais do mundo. O território que atualmente forma o Brasil foi oficialmente descoberto pelos portugueses em 22 de abril de 1500, em expedição liderada por Pedro Álvares Cabral. Em 1815, o Brasil se torna parte de um reino unido com Portugal. Dom Pedro I, o primeiro imperador, proclamou a independência política do país em 1822.'
